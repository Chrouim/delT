# %% [markdown]
# <a href="https://colab.research.google.com/github/Chrouim/delT/blob/main/Jupyter_Notebook_21WSA010_Coursework_V3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The Ecosystem Object Definition**
#
# The ecosystem is a virtual environment in a virtual universe in which virtual robots are created by the **_Chief Robot Programmer_** (CRP). The ecosytem has 'rules' which, if the robots do not follow, they can come to a premature demise. It is up to the CRP to programme their robots to follow system rules. A well programmed robot colony can thrive and prosper, if it is poorly programmed it may not perform so well.
#
# There are a number of system indicators which measure the health of the ecosystem.
#
# During the lifetime of the universe the ecosystem might evolve. This means the ecosystem rules change. Robots must therefore evolve or adapt to their new environment. The CRPs must be agile programmers.
#
# A major deadline exists on the 12-January-2022. There will be a major conference of the parties or **COP27** meeting to see whether your ecosystem is on track to meet targets and deliver a sustainable Robot ecosystem which is operating in harmony with its environment by creating a circular economy.

# %% [markdown]
# # **Ecosystem Version -  Final Release**
#
# **WSA010_Coursework_V3_2 (30) 16-Dec-21 13:00**

# %% [markdown]
# ## **Required Imports**

# %%
#@title Required Imports [code] {display-mode: "code"}
from IPython.display import clear_output
from copy import copy, deepcopy
import time
from random import randint
from sys import exit
import numpy as np
import matplotlib.pyplot as plt
import math
from queue import Queue
#from types import type - may need later

# %% [markdown]
# ## **Globals**
#
# Global variables used in the code base. Do not adjust these.

# %%
#@title Globals [code] {display-mode: "code"}

testing = False

#Ecosystem Boundaries
default_width = 80
default_height = 40
default_altitude = 5

arena_limits = (default_width,default_height,default_altitude)

#Fading of robots  alpha = m_fade * soc/capacity + c_fade
c_fade = 0.1
m_fade = 0.9 - c_fade
#deliverable fading
delivered_fade = 0.33
delivered_fade_rate = .005   #d alpha at -.5% per update

#maximum damage a robot can sustain
max_damage = 5
motion_efficiency = 0.100
system_efficiency = 0.025

NL = "\n"
TB = "\t"
PR = ">"

# %%
randcoordinates = [randint(0,m) for m in list(arena_limits[:2]) + [0]]
print (randcoordinates)
# Out:
# [61, 30, 0]

# %% [markdown]
# ## **Support Functions**
#
# The ecosystem requires all these sections to operate. Do not remove and ensure they are run before developing and running your Robots

# %%
# @title Utility functions [code] {display-mode: "code"}

#randsign generates a random -1 or +1 to give a random sign of a vector
def randsign():
  return [-1,1][randint(0,1)]

#sign returns the sign x 1 of a number.
def sign(i):
  #return [-1,1][i>0]
  return [-1,0,1][0 if i < 0 else 1 if i == 0 else 2]

#Returns the name of a variable in the namespace which points to the passed object.
#If more than name points to the object the first is returned or all if return_all is true
def namestr(obj, return_all = False):
  namespace = globals()
  if return_all:
    return [name for name in namespace if namespace[name] is obj]
  else:
    try:
      return [name for name in namespace if namespace[name] is obj][0]
    except:
      return obj # probably a literal so no name to give!

# %%
# @title Irradiance [code] {display-mode: "code"}
#Not a real estimate of irradiance since it isn't gaussian
def normpdf(x, mean, sd):
    var = float(sd)**2
    denom = (2*math.pi*var)**.5
    num = math.exp(-(float(x)-float(mean))**2/(2*var))
    pdf = num/denom
    return pdf

def irradiance(hour):
    hour = hour % 24
    mean = 12     #mid-day
    sd = 3        #standard dev of irradiance
    normalised_pdf  = normpdf(hour,mean,sd)/normpdf(mean,mean,sd)
    moonlight = 0.2
    a = moonlight + (1-moonlight)*normalised_pdf
    return a

#Test Display of irradiance over 24 hours
x,i = [],[]
for h in range(0,24*4):
  i.append (irradiance(h/4))
  x.append (h/4)
fig = plt.figure(figsize=(4,4))
ax = fig.add_subplot(111)
a = ax.plot(x,i)
a = ax.fill(x,i,'yellow')
plt.title ('Normalised Irradiance')
# Out:
# Text(0.5, 1.0, 'Normalised Irradiance')

# %% [markdown]
# ### **Defaults**
# This section defines default values for different Robot and other Ecosystem Objects. CRPs should study this section to understand the different default values assigned to
# robots of difference types.

# %%
#@title Validation Lists {display-mode: "code"}

####################
## DEFAULTS       ##
####################

# Matplotlib colors and shapes semantics # https://matplotlib.org/stable/api/markers_api.html
mpl_shapes = {'square':'s', 'circle':'o','triangle':'^', 'plus':'P', 'star':'*', 'diamond':'D', 'x':'x', 'hexagon':'h'}
mpl_colors = {'blue': 'b', 'green': 'g', 'red': 'r', 'cyan': 'c', 'magenta': 'm', 'yellow': 'y', 'black': 'k', 'white': 'w'}

colors = [color for color in mpl_colors]
shapes = [shape for shape in mpl_shapes]

modes = ['required', 'default', 'validation','function', 'datatype', 'description']

kinds = dict(
  Robot = 'Robot', 
  Droid = 'Robot', 
  Drone = 'Robot', 
  Pizza = 'Deliverable', 
  Grid_Charger = 'Station',
  Solar_Charger = 'Station', 
  Repair_Station = 'Station', 
  Recycling_Station = 'Station')

robot_statuses = [
	'off', 
	'on', 
	'broken']

deliverable_statuses = [
	'awaiting_transport',
	'awaiting_collection', 
	'in_transit',
	'delivered']

station_statuses = [
	'occupied', 
	'vacant']

activities = [
	'idle',
	'available', 
	'charging', 
	'busy', 
	'delivering', 
	'is_cargo', 
	'under_repair',
	'repairing']

# %%
#@title Validation Functions [code] {display-mode: "code"}
#nv = new value
# v = old value
#av = rule parameters 
length = lambda nv,v,av: (av[0] <= len(nv) <= av[1],nv if av[0] <= len(nv) <= av[1] else v)  #return old value if new invalid
inlist = lambda nv,v,av: (nv in av, nv if nv in av else v)     
nochange = lambda nv,v,av: (nv == v, v)
inrange = lambda nv,v,av: (av[0] <= nv <= av[1],nv if av[0] <= nv <= av[1] else v)
listdelta = lambda nv,v,av:(False not in [abs(i_nv - i_v) <= i_av for i_nv, i_v, i_av in zip(nv,v,av)], v)
listmaxdelta = lambda nv,v,av:(False not in [abs(i_nv - i_v) <= i_av for i_nv, i_v, i_av in zip(nv,v,av)], [ i_v + [-1,1][i_nv > i_v]*min(i_av,abs(i_nv-i_v)) for i_nv, i_v, i_av in zip(nv,v,av)])
onarena = lambda coordinates: (False not in [0 <= i_c <= i_l for i_c, i_l in zip(coordinates, arena_limits)], [i_c if 0 <= i_c <= i_l else -1 if i_c < 0 else i_l + 1 for i_c, i_l in zip(coordinates, arena_limits)])
listmax = lambda nv,v,av: (False not in [abs(nv[i]) <= av[i] for i in [0, 1, 2]], [nv[i] if abs(nv[i]) <= av[i] else av[i]*sign(nv[i]) for i in [0, 1, 2]])
none = lambda nv,v,av: (True,nv)

def validxyz(nv,v,av):
  #nv for new robot receives v = nv
  #av = [dx,dy,dz]  where dz >= 1 means volitant and cannnot move on the ground
  if av[2] >= 1 and nv[2] == 0 and v[2] == 0:    #volitant is on the ground and was previously
    return nv == v, v                            # if not equal then this is false so bad move
  else:    
    deltaOK, cnv = listmaxdelta(nv,v,av)  #corrected new values wrt to vector increments
    on_arena, anv = onarena(cnv)
    return deltaOK and on_arena, anv

validation_functions = {'none': none, 'listmax': listmax, 'inlist': inlist, 'nochange': nochange, 'inrange': inrange, 'listdelta': listdelta, 'listmaxdelta': listmaxdelta, 'onarena': onarena, 'validxyz': validxyz, 'length': length }

def validation(new_value, old_value, rule, function_name, verbose = True):
  proposed_value = new_value
  function = validation_functions[function_name]
  valid, new_value = function (new_value, old_value, rule)
  if verbose:
    if valid:
      if old_value == new_value:
        message = 'Value \'' + str(old_value) + '\' retained'
      else:
        message = 'Value \'' + str(old_value) + '\' set to \'' + str(new_value) + '\''
    else:
      message = 'Value \'' + str(proposed_value) + '\' rejected. ' 
      if function_name == 'length':
        message += 'Length must be between ' + str(rule[0]) + ' and ' + str(rule[1])
      if function_name == 'inrange':
        message += 'Must be between ' + str(rule[0]) + ' and ' + str(rule[1])
      elif function_name == 'inlist':
        message += 'Must be in list ' + str(rule)
      elif function_name == 'nochange':
        message += 'Cannot be changed from \'' + str(old_value) + '\''
      elif function_name == 'validxyz':
        message += 'Coordinate value or change not permitted'
      message += '. Set to ' + str(new_value) + '.'
  else:
    message = ''
  return valid, new_value, proposed_value, message

#unit tests
if False and testing:
  print (validation('xyx',None,'none','none'))
  print (validation([75, 16, 0],[78, 16, 0],[2,2,0],'none'))
  print (validation([75, 16, 0],[78, 16, 0],[2,2,0],'listmaxdelta'))
  print (validation('squre', 'triangle', shapes, 'inlist'))
  print (validation('square','triangle',shapes,'inlist'))
  print (validation('pink','red',colors,'inlist'))  
  print (validation(1,1,0,'nochange'))
  print (validation(1,2,0,'nochange'))
  print (validation([23],[24],0,'nochange'))  
  print (validation([23],[23],0,'nochange'))  
  print (validation(800,300,[200,900],'inrange'))
  print (validation(100,300,[200,900],'inrange'))  
  print (validation(1000,300,[200,900],'inrange'))    
  print (validation('shouldsucceed','testing',[3,20],'length'))
  print (validation('01234567890','shouldfail',[3,10],'length'))
  print (validation('01','shouldfail',[3,10],'length'))
  print (validation([78, 16, 0],[78, 16, 0],[2,2,0],'validxyz'))  #no change
  print (validation([77, 16, 0],[78, 16, 1],[2,2,1],'validxyz'))  #ok change
  print (validation([76, 17, 0],[78, 16, 0],[1,1,0],'validxyz'))  #too big
  print (validation([78, 14, 0],[78, 16, 0],[1,1,0],'validxyz'))  #too big  
  print (validation([56, 33, 0],[53, 36, 0],[3,3,1],'validxyz'))
  print (validation([1, 1, 0],[2, 2, 0],[2,2,0],'listmax'))
  print (validation([2, 2, 0],[2, 2, 0],[2,2,0],'listmax'))
  print (validation([-2, -2, 0],[2, 2, 0],[2,2,0],'listmax'))
  print (validation([-1, -1, 0],[2, 2, 0],[2,2,0],'listmax'))
  print (validation([-3, -3, 0],[2, 2, 0],[2,2,0],'listmax'))
  print (validation([2, 2, 1],[2, 2, 0],[2,2,0],'listmax'))

# %%
#@title Defaults [code] {display-mode: "code"}

####################
## ROBOT_DEFAULTS ##
####################

#robot_default returns a dictionary of robot instance variables, and properties 
#for these attributes

def robot_default (kind, mode = 'default'):

  kind_class = kinds[kind]
  dictionary = {}
  
  dictionary['kind'] = ['required', kind, 0, 'nochange', 'string', 'robot class type']
  if kind_class == 'Station':
    dictionary['coordinates'] = ['required', [0, 0, 0], [0, 0, 0 ], 'validxyz', 'list', 'x, y, z location of a robot']
    dictionary['max'] = ['required', [0, 0, 0], 0, 'nochange', 'list', 'maximum x, y, z velocity']
    dictionary['velocity'] = ['required', [0, 0, 0], [0 ,0 ,0], 'listmax', 'list', 'current  x, y, z velocity']
    dictionary['status'] = ['required', 'vacant',station_statuses, 'inlist', 'string', 'Set to on, off or broken']
    dictionary['activity'] = ['required', 'idle', activities, 'inlist', 'string', 'determines activity of station']
    dictionary['size'] = ['optional', 300, [250,1000], 'inrange', 'integer', 'arena display size']
    dictionary['alpha'] = ['optional', 1, 0, 'nochange', 'float', 'arena display transparency']
    dictionary['damage'] = ['recommended', 0, 0, 'nochange', 'integer', 'damage points accrued by station']
    dictionary['occupant'] = ['recommended', 0, 0, 'nochange', 'integer', 'damage points accrued by station']
    if kind == 'Grid_Charger':
      dictionary['name'] = ['required', 'gazza', [2,20], 'length', 'string', 'named of robot']
      dictionary['shape'] = ['optional', 'diamond', shapes, 'inlist', 'string', 'arena display shape']
      dictionary['color'] = ['optional', 'blue', colors, 'inlist', 'string', 'arena display colour']
    elif kind == 'Solar_Charger':
      dictionary['name'] = ['required', 'sunny', [2,20], 'length', 'string', 'named of robot']
      dictionary['shape'] = ['optional', 'diamond', shapes, 'inlist', 'string', 'arena display shape']
      dictionary['color'] = ['optional', 'green', colors, 'inlist', 'string', 'arena display colour']
    elif kind == 'Repair_Station':
      dictionary['name'] = ['required', 'fixit', [2,20], 'length', 'string', 'named of robot']
      dictionary['shape'] = ['optional', 'diamond', shapes, 'inlist', 'string', 'arena display shape']
      dictionary['color'] = ['optional', 'magenta', colors, 'inlist', 'string', 'arena display colour']
    elif kind == 'Recycling_Station':
      dictionary['name'] = ['required', 'reuse', [2,20], 'length', 'string', 'named of robot']
      dictionary['shape'] = ['optional', 'diamond', shapes, 'inlist', 'string', 'arena display shape']
      dictionary['color'] = ['optional', 'cyan', colors, 'inlist', 'string', 'arena display colour']

  elif kind_class == 'Deliverable':
    dictionary['coordinates'] = ['required', [0, 0, 0], [0, 0, 0 ], 'validxyz', 'list', 'x, y, z location of a robot']
    dictionary['max'] = ['required', [0, 0, 0], 0, 'nochange', 'list', 'maximum x, y, z velocity']
    dictionary['velocity'] = ['required', [0, 0, 0], [0 ,0 ,0], 'listmax', 'list', 'current  x, y, z velocity']
    dictionary['status'] = ['required', 'awaiting_transport',deliverable_statuses, 'inlist', 'string', 'Set to on, off or broken']
    dictionary['activity'] = ['required', 'idle', activities, 'inlist', 'string', 'determines activity of deliverable']
    dictionary['size'] = ['optional', 300, [250,1000], 'inrange', 'integer', 'arena display size']
    dictionary['alpha'] = ['optional', 1, 0, 'nochange', 'float', 'arena display transparency']
    dictionary['weight'] = ['optional', 50, [25,1000], 'nochange', 'integer', 'weight of deliverable']
    dictionary['damage'] = ['recommended', 0, 0, 'nochange', 'integer', 'damage points accrued by deliverable']  
    dictionary['name'] = ['required', 'pizza', [2,20], 'length', 'string', 'named of deliverable']
    dictionary['target'] = ['recommended', None,'none', 'none', 'list', 'x, y, z of delivery destination']    
    dictionary['shape'] = ['optional', 'circle', shapes, 'inlist', 'string', 'arena display shape']
    dictionary['color'] = ['optional', 'white', colors, 'inlist', 'string', 'arena display colour']
    dictionary['transport'] = ['optional', None,'object', 'nochange', 'object', 'object robot is transporting']
    dictionary['start'] = ['optional', 0, 0, 'none', 'float', 'start time stamp']
    dictionary['end'] = ['optional', 0, 0, 'none', 'float', 'end time stamp']

  elif kind_class == 'Robot':
    dictionary['coordinates'] = ['required', [0, 0, 0], [1, 1, 0 ], 'validxyz', 'list', 'x, y, z location of a robot']
    dictionary['max'] = ['required', [1, 1, 0], 0, 'nochange', 'list', 'maximum x, y, z velocity']
    dictionary['velocity'] = ['required', [0, 0, 0], [1 ,1 ,0], 'listmax', 'list', 'current  x, y, z velocity']
    dictionary['status'] = ['required', 'on',0, 'nochange', 'string', 'Set to on, off or broken']
    dictionary['activity'] = ['required', 'idle', activities, 'inlist', 'string', 'determines activity of robot']
    dictionary['name'] = ['required', 'id', [2,20], 'length', 'string', 'named of robot']
    dictionary['target'] = ['recommended', None,'none', 'none', 'list', 'x, y, z of a target destination']
    dictionary['age'] = ['recommended', 0, 0, 'nochange','integer', 'age of robot in hours']
    dictionary['active'] = ['recommended', 0, 0, 'nochange','integer', 'active hours of robot']    
    dictionary['serviced'] = ['recommended', 0, 0, 'nochange','integer', 'age of robot at last service']
    dictionary['soc'] = ['recommended', 600, 0, 'nochange', 'integer', 'state of charge of battery']
    dictionary['capacity'] = ['recommended', 600, 0, 'nochange', 'integer', 'energy capacity of robot battery']
    dictionary['service'] = ['recommended', 0, 0, 'nochange', 'integer', 'service points accrued by robot']
    dictionary['damage'] = ['recommended', 0, 0, 'nochange', 'integer', 'damage points accrued by robot']
    dictionary['on_arena'] = ['optional', 0,0, 'nochange', 'boolean', 'True if robot is on the arena']
    dictionary['shape'] = ['optional', 'square', shapes, 'inlist', 'string', 'arena display shape']
    dictionary['color'] = ['optional', 'blue', colors, 'inlist', 'string', 'arena display colour']
    dictionary['size'] = ['optional', 250, [250,1000], 'inrange', 'integer', 'arena display size']
    dictionary['alpha'] = ['optional', 1, 0, 'nochange', 'float', 'arena display transparency']
    dictionary['weight'] = ['optional', 50, 0, 'nochange', 'integer', 'weight of robot']
    dictionary['payload'] = ['optional', 100, 0, 'nochange', 'integer', 'maximum load of robot']
    dictionary['cargo'] = ['optional', None,'object', 'none', 'object', 'object robot is transporting']
    dictionary['station'] = ['optional', None,'object', 'none', 'object', 'station robot is heading for']
    dictionary['distance'] = ['optional', 0, 0, 'nochange', 'float', 'distance travelled by robot']
    dictionary['energy'] = ['optional', 0, 0, 'nochange', 'float', 'energy consumed by robot']
    
    if kind == 'Droid':
      dictionary['coordinates'][2] = [2, 2, 0 ]
      dictionary['max'][1] = [2, 2, 0 ]
      dictionary['velocity'][2] = [2, 2, 0 ]
      dictionary['soc'][1] = 2000
      dictionary['capacity'][1] = 2000
      dictionary['shape'][1]= 'circle'
      dictionary['color'][1] = 'red'
      dictionary['size'][1] = 300
      dictionary['weight'][1] = 100
      dictionary['payload'][1] = 200
    elif kind == 'Drone':
      dictionary['coordinates'][2] = [3, 3, 1]
      dictionary['max'][1] = [3, 3, 1]     
      dictionary['velocity'][2] = [3, 3, 1 ]    
      dictionary['soc'][1] = 500      
      dictionary['capacity'][1] = 500
      dictionary['shape'][1] = 'triangle'
      dictionary['color'][1] = 'green'
      dictionary['size'][1] = 500
      dictionary['weight'][1] = 25
      dictionary['payload'][1] = 50
  dictionary['kind_class'] = ['optional', kind_class, 0, 'nochange', 'string', 'class of kind']
  
  try:
    if mode == 'dictionary':
      return dictionary
    elif mode == 'keys':
      return tuple(key for key in dictionary)
    else:
      index = modes.index(mode)                                      
      return {key: value[index] for key, value in dictionary.items()}
  except:
    pass

# %%
#@title Defaults Tests [code] {display-mode: "code"}
local_testing = True and testing
if local_testing:
  for kind in kinds.keys():    #  ['Robot','Droid','Drone']:
    for return_type in ['dictionary','default']:
      print(kind, return_type,robot_default(kind, return_type))
  for return_type in ['keys', 'required', 'validation','function','datatype', 'description']:   
    print(return_type,robot_default('Robot', return_type))

  print ('Deliberate Error Raise test:')
  print ('Invalid mode:',robot_default('Robot','key'))

# %% [markdown]
# ### **Display**
#
# The display is designed to display individual robots on the robot arena. It receives a list of robot registers when ```ecosystem.display()``` is executed. Display is documented in the Ecosystem documentation.

# %%
# @title Display Function [code] {display-mode: "code"} 
#%matplotlib inline

def display(markers,**kwargs):
  cm = 1/2.54
  width = kwargs.get('width', 30)*cm
  height = kwargs.get('height', 15)*cm
  pause = kwargs.get('pause', 250)
  title = kwargs.get('title','Ecosystem Display')
  clear = kwargs.get('clear',True)
  hour =  kwargs.get('hour', 12)
  brightness = kwargs.get('brightness', False)
  facecolor =  kwargs.get('facecolor', 'yellow')
  annotations = kwargs.get('annotations', [])
  annotate = len(annotations) > 0
  if annotate:
    try:
      if type(annotations[0]) == tuple:
        dx,dy = annotations[0][0],annotations[0][1]
      else:
        dx,dy = 1, 1
    except:
      pass

  try:
    title = title.format(**kwargs)
  except Exception as error:
    title = title + ' #format missing ' + str(error) + '#'

  x_max =  default_width
  y_max =  default_height

  if clear:
    clear_output(wait=True)
 
  a = irradiance(hour) if brightness else 1


  fig = plt.figure(figsize=(width,height))
  fig.patch.set_facecolor('grey')
  fig.patch.set_alpha(0.6)
  ax = fig.add_subplot(111)
  ax.patch.set_facecolor(facecolor)
  ax.patch.set_alpha(a)

  plt.title (title)
  plt.xlim(-2, x_max+2)
  plt.ylim(-2, y_max+2)
  for p in markers:
    try:
      x=p['coordinates'][0]
      y=p['coordinates'][1]
      scale = p['size']
      color = p['color'] 
      shape = p['shape']
      alpha = p['alpha']
      marker_shape = mpl_shapes[shape] 
      ax.scatter(x, y, s=scale, c=color, marker=marker_shape, alpha=alpha, edgecolors='b')
      if p['coordinates'][2] > 0:
        ax.scatter(x, y, s=scale*3, c='k', marker='1', alpha=alpha, edgecolors='b')    #add helcoptor wings
      if annotate:
        try:
          annotation =  ';'.join(key + ":" + str(value) for key, value in p.items() if key in annotations)
          plt.annotate(annotation, (x+dx, y+dy),)
        except:
          pass

    except Exception as error:
      #print("Point error:", p, error)
      continue
    
  ax.set_xticks(range(0, x_max + 1, 10))
  ax.set_yticks(range(0, y_max + 1, 10))
  ax.grid(color = 'red', linestyle = '--', linewidth = 0.25)

  plt.show()
  time.sleep(pause/1000)

# %%
#@title Display Tests {display-mode: "code"}
if testing:
  points = []

  for kind in ['Robot', 'Drone', 'Droid', 'Grid_Charger', 'Solar_Charger','Repair_Station','Recycling_Station', 'Pizza', 'Pizza']:
    register = robot_default(kind, 'default')
    alt_max = 1 if kind == 'Drone' else 0
    register['coordinates'][0] = randint (0, default_width)
    register['coordinates'][1] = randint (0, default_height)
    register['coordinates'][2] = randint (0, alt_max)
    points.append(register)
     
  display(points, facecolor = 'pink',title = "Ecosystem Display Hour:{hour} Registered:{registered}", annotations = [(1.5,0),'soc','name'], hour = 12, registered = len(points))
  for p in points:
    print (p)

# %% [markdown]
# ## **Ecosystem Class**

# %%
########################################################
# @title Ecosystem Class [code] {display-mode: "code"}
########################################################

class Ecosystem:
  def __init__(self):
    #Constructor - called when a new object is created using the class
    #Attributes or properties
    self._duration = 24
    self._hour = 0
    self._robots = []
    self.display_on_update = False
    self._register = {}
    self.markers = []
    self._messages = Queue()
    self._cache = {}
    self._registerable = [ kind for kind in kinds]
    self.random_cordinates = True
    self.message_types = [ 'damage', 'error', 'info', 'broken']     #''warning''
    self._display_parameters = {}
    self._delivered = {}  #cache of delivered objects transferred from live register

 ####################
 ##   Properties   ##
 ####################

  @property 
  def display_parameters(self):
    return self._display_parameters
  @property
  def has_message(self):
    return not self._messages.empty()   #while not q1.empty():
  @property
  def messages(self):
    text = ''
    while self.has_message:
      #messages are a tuple of 5 objects
      message_type, kind, name, function, comment = self.message
      try:
        text += f'{message_type:<10} {kind:<8} {str(name):<16} {function[:12]} {comment}' + '\n'
      except:
        text += str([message_type, kind, name, function, comment])
    return text
  @property
  def message(self):
      if self._messages.empty():
        return False
      else:
        return self._messages.get()
  @message.setter
  def message(self, value):
    try:
      if value[0] in self.message_types:
        self._messages.put(value)
    except TypeError:
      pass
  @property
  def robots(self):
      return [robot for robot in self._robots if robot.kind in ['Robot', 'Droid', 'Drone']]
  def things (self, kind):
      return [thing for thing in self._robots if thing.kind == kind]
  @property
  def robot_register(self):
    return self._register
  @property
  def duration(self):
      return self._duration
  @duration.setter
  def duration(self, value):
      self._duration = value
  @property
  def hour(self):
      return self._hour
  @property
  def count_operational(self):
    count = len([value for value in self._register.values() if value['status'] == 'on'])
    return count
  @property
  def stop(self):
    return self._hour>self._duration
  @property
  def operational(self):
    return self.count(status = 'on')
  @property
  def broken (self):
    return self.count(status = 'broken')

####################
##   Object       ##
####################

  def create(self, kind, coordinates = [0,0,0]):
    def object_init(self,dictionary):
      for k, v in dictionary.items():
        setattr(self, k, v)

    try:
      if kind in self._registerable:       #<-Check if a registerable object
        register = robot_default(kind)
        New_Object = type(kind,(),{"__init__":object_init})   #lambda self,dictionary: (setattr(self, k, v) for k, v in dictionary.items()) tried to use but Lambda cannot return None which init expects
        new_object = New_Object(register)

        if new_object.kind_class == 'Deliverable':
          if coordinates != [0,0,0]:
            raise ValueError("Robot controllers cannot decide where to collect a " + kind)
          new_object.target = [randint(0,default_width), randint(0,default_height), 0]

        new_object.coordinates[0] = coordinates [0]
        new_object.coordinates[1] = coordinates [1]
        new_object.start = ecosystem.hour
        self.register(new_object)
        return new_object
      else:
        raise TypeError("The ecosystem can't create a " + str(kind))
    except Exception as error:
      print('>>', 'create error')
      self.message = ('error', kind, 'None', 'create', error)

####################
##   METHODS      ##
####################
  def help(self):
    for a in [a for a in dir(self) if not a.startswith('_') and callable(getattr(self, a))]:
      print (a)

  def count (self, **kwargs):
    count = len(self.registry(**kwargs))
    return count

  def registry(self, **kwargs):
    if kwargs == {}:
      return self._register
    else:
      try:
        return {key: value for key, value in self._register.items() if (False not in [value[filter_key] == filter_value for filter_key, filter_value in kwargs.items()])}
      except Exception as error:
        return "Could not filter register using "   + str(kwargs) + ' ' + str(error)

##   DISPLAY       ##
  def display (self):
    markers = self._get_markers()

    title = self.display_parameters.get('title')
    if title is not None:
      for word in title.split():
        print(word)
        if word[0] == "{" and word[-1] == "}":
          attribute = word[1:-1]
          self.display_parameters[attribute] = getattr(self, attribute,'#error#')
          print (attribute, self.display_parameters[attribute] , getattr(self, attribute,'#error#'))
    display(markers, **self.display_parameters)

##   MARKERS       ##
  def _get_markers(self):
    self.markers = [value for value in self._register.values()]
    return self.markers
 
 ##   REGISTER  ##
  def register (self, *args):
    for robot in args:
      kind = type(robot).__name__
      if kind in self._registerable:       #<-Check if a registerable object
        if robot in self._robots:          #<-Check if already in the register
          self.message = ('warning', kind, robot.name, 'register', 'already registered')
        else:
          try:                            #\>Try get default from cache
            dictionary = self._cache[kind]
          except:                         #/>auto heal the cache
            dictionary = robot_default(kind, 'dictionary')
            self._cache[kind] = dictionary

          #Get a new register copy from the dictionary. Upgrade Caution - index for default values fixed to 1
          register = deepcopy({key: value[1] for key, value in dictionary.items()})

          #Resolve co-ordinate updating
          #if the user has provided coordinates check if these are defaults and if not, set to defaults
          coordinates = getattr(robot,'coordinates', register['coordinates'])
          #if the coordinates are defaults and they should be random then randomize x and y.
          if register['coordinates'] == coordinates and self.random_cordinates:
            coordinates[0] = randint(0,default_width)
            coordinates[1] = randint(0,default_height)
            try:
              #update the object with the new random co-ordinates.
              #do not detect and error here as that will come in the round later
              setattr( robot,'coordinates', coordinates)
            except:
              pass
          #reset xy coordinates in the register to reflect changes and prevent speeding
          #however drones cannot start with z>1 so let error handling pick that up
          register['coordinates'][0] = coordinates[0]
          register['coordinates'][1] = coordinates[1]

          for key, register_value in register.items():
            value = dictionary[key]
            #sequence unpack the dictionary value list with indexes  0,2,3
            required, rule, function_name = [value[index] for index in [0,2,3]]
            try:
              new_value = getattr(robot, key)         #exception if not an available instance variable
              valid, new_value, proposed_value, message = validation (new_value, register_value, rule, function_name)
              if valid == False:
                self.message = ('damage', kind, id(robot), 'register', '\'' + key + '\' error: ' + message)
                register['damage'] += 1
                if hasattr (robot,'damage'):
                  setattr(robot,'damage', register['damage'])
              register[key] = copy(new_value)         #even tho proposed_value may be rejected, new_value is always good so update it!'
            except Exception as error:
              if required == 'required':              #required instance variable not present
                self.message = ('error', kind, id(robot), 'register', 'required variable \'' + key + '\' missing. ' + kind + ' not registered')
                break
              elif required == 'recommended':         #recommened instance variable not present
                self.message = ('warning', kind, id(robot), 'register', 'recommended variable \'' + key + '\' missing')
          else:                                       #rare use of else. Register robot if no break executed
            self._robots.append(robot) 
            self._register[id(robot)] = register
            self.message = ('info', kind, id(robot), 'register', kind + ' registered with ' + str(register['damage']) + ' damage points' )
      else:
        self.message = ('error', kind, id(robot), 'register', 'attempt to register an invalid object type')
      #/if kind in self._registerable
    #/for robot in args  

  def deregister (self, *args):
    for robot in args:
      try:
        del self.robot_register[id(robot)]
        self.robots.remove(robot)
        del robot
      except:
        pass

## UPDATE ##
  def update(self):
    for robot in self.robots:                             #note - robots now contains pizzas, so use the internal property which filters
      dictionary = self._cache[robot.kind]                #get the dictionary for validation purposes
      register = self._register[id(robot)]                #get the current register
      coordinates = copy(register['coordinates'])         #used for later distance calculation
      if register['status'] == 'on':                      #if 'on' update new register from robot, ignore if not present
        for key, register_value in register.items():
          try:
            robot_value = getattr(robot, key)         #exception if not an available instance variable
            if robot_value != register_value:
              value = dictionary[key]
              required, rule, function_name = [value[index] for index in [0,2,3]]
              valid, validated_value, proposed_value, message = validation (robot_value, register_value, rule, function_name)
              #print(">>>", valid, validated_value, proposed_value, message )
              if valid == False:
                self.message = ('damage', robot.kind, id(robot), 'update', '\'' + key + '\' error: ' + message)
                register['damage'] += 1
                if hasattr (robot,'damage'):
                  setattr(robot,'damage', register['damage'])
              #register[key] = copy(validated_value)         #even tho proposed_value may be rejected, new_value is always good so update it!'                  
              #somethings making the coordinates the same so checking this line: with copy
              register[key] = validated_value         #even tho proposed_value may be rejected, new_value is always good so update it!'
          except Exception as error:
            #print (error)
            pass

      # increment age regardless of anything
      register['age'] += 1

      if register['status'] == 'on':
        register['active'] += 1
        cargo_weight = 0
        cargo = register['cargo']
        if cargo is not None:
          if cargo.status == 'awaiting_transport':
            if cargo.coordinates != register['coordinates']:  
              cargo.status = 'awaiting_collection'
          if cargo.status == 'awaiting_collection':
            if cargo.coordinates == register['coordinates']:
              #robot has arrived at collection point, so load up.
              cargo.status = 'in_transit'
              cargo.size = 200
              cargo.shape = 'square'
              cargo.color = 'red'
              cargo_weight = cargo.weight
          if cargo.status == 'in_transit':
            cargo.coordinates = copy(register['coordinates'])
            if cargo.coordinates == cargo.target:
              #arrived at destination
              cargo.status = 'delivered'
              cargo.color = 'white'
              cargo.shape = 'circle'
              cargo.alpha = delivered_fade
              cargo.end = ecosystem.hour
              register['service'] += cargo.weight
          self._register[id(cargo)] = cargo.__dict__
        
        #Charging station
        station = register['station']
        if station is not None:  
          if station.status == 'vacant':
            if station.coordinates == register['coordinates']:
              station.status = 'occupied'
              station.occupant = robot
              station.color = 'cyan'
              station.size = 1000
          elif station.status == 'occupied':
            if station.occupant is robot:
              register['soc'] = register['capacity']
              station.status = 'vacant'
              station.occupant = None
              station.color = 'blue'
              station.size = 250
          self._register[id(station)] = station.__dict__
   
        #using cache of coped coordinates becasue validation destroys change for calculation of distance      
        distance = round(((register['coordinates'][0] - coordinates[0])**2 + (register['coordinates'][1] - coordinates[1])**2)**.5,1)      
        register['distance'] += distance
        
        height = max(robot.coordinates[2] - register['coordinates'][2],0) #not used in energy calcs yet!
              
        motion_energy = (register['weight'] + cargo_weight) * distance * motion_efficiency
        system_energy = register['weight'] * system_efficiency
        energy = int(min(system_energy + motion_energy, register['soc']))
        register['energy'] += energy
        register['soc'] = int(register['soc'] - energy)
        #register['soc'] = round(max(register['soc'], 0),2)
        
        

        if onarena(register['coordinates'])[0] == False:
          register['damage'] += max_damage
          self.message = ('damage', robot.kind, robot.name, 'update', 'damage at ecosystem boundary') 
        if register['damage'] >= max_damage:
          self.message = ('broken', robot.kind, robot.name, 'update', 'max damage score')
          register['status'] = 'broken'
        if register['soc'] < 1:
          if station is not None and station.coordinates == register['coordinates']:
            #low charge robot is in queu for charger so do not break
            self.message = ('warning', robot.kind, robot.name, 'update', 'out of power in charger queue') 
          else:
            register['status'] = 'broken'
            self.message = ('broken', robot.kind, robot.name, 'update', 'out of power') 

        if register['status'] == 'broken':
          register['alpha'] = 0.2
          print ('broken', register)
        else:
          #alpha  determines the transparency of robots. Running out of fuel makes robots fade
          register['alpha'] = m_fade * register['soc']/register['capacity'] + c_fade
      # End of status != off block 

      for key, value in register.items():    # updating available Robot attributes
        if hasattr(robot,key):
          if key == 'coordinates':
            setattr(robot,key,copy(value))
          #setattr(robot,key,copy(value))
          else:
            setattr(robot,key,value)

    #remove faded delivered to the delivered cache and
    delivered = {key:value['alpha'] for key, value in self._register.items() if value['status'] == 'delivered'}
    for key, alpha in delivered.items():
      if alpha == 0:
        self._delivered[key] = ecosystem.robot_register.pop(key)  #transfer
      else:
        ecosystem.robot_register[key]['alpha'] = max(alpha - delivered_fade_rate, 0)

    self._hour += 1  
    if self.display_on_update:
      self.display()

# %% [markdown]
# #**Ecosystem Documentation**

# %% [markdown]
# ##**Policies**
# ---
# The Ecosystem system sets a standard for design policies which all CRPs must adhere too.
#
# * For security **only** use instance variables should be use and class variables should be deprecated, i.e. those defined and assigned in the constructor method.
#
# * Robot Classes must be self contained within their own code cells for clarity of purpose and assessment, commented as appropriate. Instantiation and registration testing of classes should be separate
#
# * Where appropriate CRPs should augment code cells comments with text cells to document and explain designs for third parties and assessment in the final submission.

# %% [markdown]
# ## **Ecosystem Rules**
#
# _The current version rules are as follows_
#
# ___
# Rules are only enforced when an ecosystem.update() call is made. All attributes are inspected, and values and changes are validated.
#
# **Registerable Objects**
#
# Only objects with the following (case sensitive) class names can be registered.
# ```
#  Robot
#  Droid
#  Drone
# ```
# Attempts to register anything fails. Registration failure wastes ecosystem finite resources.
#
# **Required Attributes**
# Objects must have the required attributes as documented in the Robot Class Specifications. Absence of required attributes causes registration failure. Registration failure wastes ecosystem finite resources!
#
# **Read Only**
#
# You can implement, in your Robots any of the attributes in the Robot attributes tables. A large number are read only. You can only set the value to the default value prior to registering a new robot with the ecosystem. Attempts to change a read-only values cause damage. Robots accrue 1 damage point per change attempt.
#
# **Speed**
#
# Robots must not move more than the following increments between updates in the $x$, $y$ and $z$  directions. You can regard this as a nominal maximum speed, though of course moving diagonally is permitted and this increases the speed by factor of  $\sqrt{2}$ (if $\Delta x=1$ and $\Delta y = 1$). This is permitted. The main point is to adhere to permitted $x$, $y$ or $z$ increments.
#
# |       | 𝜟x | 𝜟y | 𝜟z |
# |:-----:|:--:|:--:|:--:|
# | Robot | 1  |  1 |  0 |
# | Droid | 2  |  2 |  0 |
# | Drone | 3  |  3 |  1 |
#
# Robots and Droids (non-[volitants](https://en.wiktionary.org/wiki/volitant)) can never move in the $z$ axis. They cannot fly. Furthermore, for Drones, (volitants) the following implicit rule applies:
#
# | 𝜟x | 𝜟y | 𝜟z | $\Rightarrow$ z |
# |:-:|:-:|:-:|:--:|
# | 0 | 0 | 1 |  0 |
# | 3 | 3 | 1 | >0 |
#
# In other words Drones can only move in the air. If they are on the ground they cannot move, unless $\Delta z>0$  (upwards). Note that if they are taking off, or landing, such that either the start point or end point (but not both), is $z=0$ then they can move laterally too. I.e. vertical take offs are not mandated by this rule.
#
# If a robot speeds the move is cancelled. Speeding causes damage of **1 damage point** per attempted speeding incident (i.e. regardless of the number of vectors involved).
#
# **Respecting Ecosystem Boundaries**
#
# * Ecosystem boundaries in all dimensions must be respected. The limits are documented in the section **Ecosystem>Globals**:
# >
# >#Ecosystem Boundaries
# >
# >default_width = 80
# >
# >default_height = 40
# >
# >default_altitude = 5
#
# * The lower limits are all 0.
#
#     **Note** do not _hardwire_ boundaries when programming to respect this rule - you should always use variable names in case boundaries change in a future ecosystem release.
# A robot can _sit_ on the boundary. A Robot coordinate must not go negetive, or greater than the boundary limit. Failure to respect boundaries causes immediate malfunction of a robot. Its status is immediately set to ```broken```.
#
# An attempt to move beyond the system boundaries results in severe damage amounting to **the maximum permitted damage points**. Therefore it will break down!
#
# **Robot Status**
# A robot has one of three statuses#
#
# > on
# >
# > off
# >
# > broken
#
# The default status for a new Robot is ```on```. A robot's status is set to broken if:
#
# * It runs out of charge (```soc = 0```)
# * It gets the maximum permitted damage points
# * The robot goes beyond the ecosystem boundary.

# %% [markdown]
# ##**Ecosystem Interface**
# ---
#
# The **ecosysystem class** provides an interface with a constructor method, a number of public **methods** and **properties** which are important for the CRP.
#
# **Constructor**
#
# There are no arguments required nor accepted by the constructor
#
# > ecosystem = Ecosystem()
#
# **Public properies**
#
# > robots - returns a ```list``` of all registered robot objects (read only)
# >
# > registry - returns a dictionary which is full register of all registered robots. It is a dictionary of individual robot register as the value, and the robot object id() value as the key. A robot register contains a copy a Robot's attributes and is a valid data point for the chart. The method can accept key word arguments consisting of a robot attributes and an expected values in order to filter the registry. Thus
# ``` ecosystem.registry(kind = "Drone")```
# will filter the registry for Drone objects only.
# >
# > duration - returns an integer which is the duration of the ecosystem in hours (default 24) (read/write). Use by the ```stop``` property.
# >
# > hour - returns an integer for the current hour of operation. Used by the stop property and also for calculating the age of robots (read only)
# >
# > stop - return a boolean true value if ```hour >= duration``` (read only)
# >
# > count_operational - returns an integer which is the count of robots with ```status = 'on'``` (read only)
# >
# > messages  - returns a formatted list of all the fifo message stack (read only)
# >
# > message - returns a tuple message in the fifo message stack, or false if none is available. (read/write)
# >
# > has_message - returns true if there are unread messages in the message stack
# >
# > display_on_update - boolean to determine of the robot arena is auto-refreshed on update
# >
#
# **Methods**
# >
# > display(**kwargs) - displays the robot arena and render the robot objects
# >
# >   > arguments: kwargs - see chart
# >
# > register(robot) - registers a robot to participate in ecosystem activities
# >
# >   > robot: a valid robot object class/subclass
# >
# > update(**kwargs) - updates the robot register with new values for all attributes, validates permitted changes and makes necessary updates to system variables. If display_on_update is true the robot arena is updated.
# >
# >   arguments: kwargs are passed to the display method- see chart
# >

# %% [markdown]
# ##**Display**
# ---
# The display is updated everytime the ecosystem is updated if the ecosystem attribute ```display_on_update = True```. This can be set to False to perform rapid simulations.
#
# You can also call display directly for test purposes which bypasses Ecosystem updating, so you can visualise the results of robot programming without ecosystem constraints!
#
# Calling display
#
# >
# > display (markers, **kwargs)
# >
# > arguments:
# >
# > markers: a list of ecosystem robot registers.
# >
# > kwargs: (keyword arguments)
# > >
# > > width  - integer,  width of chart in cm default = 30
# > >
# > > height - integer, height of chart in cm default = 15
# > >
# > >pause - integer, delay time in ms after displaying chart default = 250
# > >
# > >title - string, text displayed on chart default = 'Ecosystem Display'
# > >
# > >clear - boolean, clears code cell output area prior to display (default = True)
# > >
# > >hour - ecosystem time in hours (default = 12)
# > >
# > >annotations - list of attributes to display in a point annotation (default = none).

# %% [markdown]
# # **Robot Documentation**

# %% [markdown]
# ## **Robot Class Specifications**
# ---
# This section defines the _**interface**_ for your Robots. For our purpose this means instance variables and methods.
# >>
# _for security purposes CRPs must **only** use instance variables, i.e. those defined and assigned in the constructor method (see ecosystem policies)._
#
#
# * **Inheritance** - Robot is the parent class from which all other robot kinds inherit. Each class can have it's own constructors and methods and/or you can use [inheritance and override methods](https://www.w3schools.com/python/python_inheritance.asp) as documented in **JNBV08**
#
# * **Attributes** are documented for each class in the attribute tables below. Attribute must be assigned in the constructor class. You will note the table lists **required**, **recommended** and **optional** attributes. These differ as follows:
#
#   * Required - each Robot class ***must*** have the **required** attributes. If these _instance variables_ do not exist in the class the ecosystem will fail to register the robot objects.
#   * Recommended - this variables are recommended because having their values to hand in your objects might help make appropriate decisions when operating in the ecosystem.
#   * Optional - these may be useful and/or become recommended or required in later stages.
#
#   * When assigning assigning the variables in the constructor class you must respect the data validation rules prior to registering the robot with the ecosystem. See Ecosystem Rules for more information. Specifically:
#     * Read only attributes must be assigned the given default.
#     * Other attributes - these have set validation rules which must be adhered to.
#     * To get started, using the default values for **all** Robot attributes is recommended.
#
# * **Methods**  Methods must be designed so that a robot can achieve desired objectives. These are discussed below under Robot Methods.

# %% [markdown]
# ##**Attribute Tables**
# ---
#
# All Robot kinds should be furnished with instance variables (which here we also call attributes) in the constructor method for the class, using the self._atttribute_name_ to assign the variable to the default value.
#
# Drones and Droids have the same variable requirements as Robots, but some of their defaults, (and validations) are different as given in the tables below.
#
# Variables given a 'Read Only' designation must, if used, be assigned the listed default value.
#
# _**Note** the validation for co-ordinates and velocity are identical to the maximum vector velocities. This means the change in co-ordinates, and velocity must respect the maximum velocity values. Co-ordinates are further validated by the requirement that they must within or on the system boundary. See ecosystem rules for more information._
#
# **Robot Class Attributes**
#
# |required    |name       |default   |validation  |datatype    |description                             |
# |------------|-----------|----------|------------|------------|----------------------------------------|
# |required    |kind       |Robot     |Read Only   |string      |robot class type                        |
# |required    |coordinates|[0, 0, 0] |[1, 1, 0]   |list        |x, y, z location of a robot             |
# |required    |max        |[1, 1, 0] |Read Only   |list        |maximum x, y, z velocity                |
# |required    |velocity   |[0, 0, 0] |[1, 1, 0]   |list        |current  x, y, z velocity               |
# |required    |status     |on        |Read Only   |string      |Set to on, off or broken                |
# |required    |activity   |idle      |activities  |string      |determines activity of robot            |
# |required    |name       |id        |[2, 20]     |string      |named of robot                          |
# |recommended |target     |None      |none        |list        |x, y, z of a target destination         |
# |recommended |age        |0         |Read Only   |integer     |age of robot in hours                   |
# |recommended |active     |0         |Read Only   |integer     |active hours of robot                   |
# |recommended |serviced   |0         |Read Only   |integer     |age of robot at last service            |
# |recommended |soc        |600       |Read Only   |integer     |state of charge of battery              |
# |recommended |capacity   |600       |Read Only   |integer     |energy capacity of robot battery        |
# |recommended |service    |0         |Read Only   |integer     |service points accrued by robot         |
# |recommended |damage     |0         |Read Only   |integer     |damage points accrued by robot          |
# |optional    |on_arena   |0         |Read Only   |boolean     |True if robot is on the arena           |
# |optional    |shape      |square    |shapes      |string      |arena display shape                     |
# |optional    |color      |blue      |colors      |string      |arena display colour                    |
# |optional    |size       |250       |[250, 1000] |integer     |arena display size                      |
# |optional    |alpha      |1         |Read Only   |float       |arena display transparency              |
# |optional    |weight     |50        |Read Only   |integer     |weight of robot                         |
# |optional    |payload    |100       |Read Only   |integer     |maximum load of robot                   |
# |optional    |cargo      |None      |object      |object      |object robot is transporting            |
# |optional    |station    |None      |object      |object      |station robot is heading for            |
# |optional    |distance   |0         |Read Only   |float       |distance travelled by robot             |
# |optional    |energy     |0         |Read Only   |float       |energy consumed by robot                |
# |optional    |kind_class |Robot     |Read Only   |string      |class of kind                           |
#
#  **Droid Class Attributes**
#
# |required    |name       |default   |validation  |datatype    |description                             |
# |------------|-----------|----------|------------|------------|----------------------------------------|
# |required    |kind       |Droid     |Read Only   |string      |robot class type                        |
# |required    |coordinates|[0, 0, 0] |[2, 2, 0]   |list        |x, y, z location of a robot             |
# |required    |max        |[2, 2, 0] |Read Only   |list        |maximum x, y, z velocity                |
# |required    |velocity   |[0, 0, 0] |[2, 2, 0]   |list        |current  x, y, z velocity               |
# |recommended |soc        |2000      |Read Only   |integer     |state of charge of battery              |
# |recommended |capacity   |2000      |Read Only   |integer     |energy capacity of robot battery        |
# |optional    |shape      |circle    |shapes      |string      |arena display shape                     |
# |optional    |color      |red       |colors      |string      |arena display colour                    |
# |optional    |size       |300       |[250, 1000] |integer     |arena display size                      |
# |optional    |weight     |100       |Read Only   |integer     |weight of robot                         |
# |optional    |payload    |200       |Read Only   |integer     |maximum load of robot                   |
#
#  **Drone Class Attributes**
#
# |required    |name       |default   |validation  |datatype    |description                             |
# |------------|-----------|----------|------------|------------|----------------------------------------|
# |required    |kind       |Drone     |Read Only   |string      |robot class type                        |
# |required    |coordinates|[0, 0, 0] |[3, 3, 1]   |list        |x, y, z location of a robot             |
# |required    |max        |[3, 3, 1] |Read Only   |list        |maximum x, y, z velocity                |
# |required    |velocity   |[0, 0, 0] |[3, 3, 1]   |list        |current  x, y, z velocity               |
# |recommended |soc        |500       |Read Only   |integer     |state of charge of battery              |
# |recommended |capacity   |500       |Read Only   |integer     |energy capacity of robot battery        |
# |optional    |shape      |triangle  |shapes      |string      |arena display shape                     |
# |optional    |color      |green     |colors      |string      |arena display colour                    |
# |optional    |size       |500       |[250, 1000] |integer     |arena display size                      |
# |optional    |weight     |25        |Read Only   |integer     |weight of robot                         |
# |optional    |payload    |50        |Read Only   |integer     |maximum load of robot                   |

# %% [markdown]
# ##**Robot Methods**
# ---
# You need to define methods and supporting attributes to help control and manage robots within your own operational strategy for the ecosystem.
#
# A recommended design strategy is documented below, but alternative designs are welcome.
#
# **Moving**
#
# The key ability of a robot is to move, whilst obeying ecosystem rules is essential. Moving means changing the coordinates ```[x, y, z]```. Robots can in theory be made to move my setting their coordinates from outside.
#
#     rob = Robot('robbo')
#     rob.coordinates = [21,13,0]
#     ecosystem.update
#
# As long as the move did not transgress the ecosystem rules for movement, your robot should be ok. However, if we are to follow the priniples of object oriented design, we should **encapsulate** the move behavour in methods for the base class, Robot.
#
# Two attributes of the classes exist which can be used to design an efficient move method to update coordinates.
#
#     self.max
#     self.velocity
#     self.coordinates
#
# It is recommended you design a move method, which changes the ```coordinates``` of a robot. The method should respect the configuration of ```velocity``` (3 vectors, positive or negetive), the maximum **absolute** values of the permitted velocity given by ```max```. Any changes to coordinates, and the system boundary.
#
# **Targetting**
# You robot has to learn to respond to an instruction to go to  specific location. this is a necessary skill when it is in a fully operating ecosystem.
#
# It is recommended therefore you furnish robots with the ```target``` attribute (default ```None```) which represents a set of $x, y, z$ coordinates for a target designation (it is uncertain whether sky targets will exist in the future).
#
# Your ```velocity``` attribute can be adjusted before each update i.e. in the update loop, to respond to a robots current ```coordinates``` and the ```target``` coordinates, whilst of course respecting the ```max``` value . This will require some careful thinking.

# %% [markdown]
# #**Courseworks Stages**

# %% [markdown]
# # **Stage 1 - Robot Classes**
# ---
# **Tasks**
#
# * Train yourself on the Ecosystem - see Stage 1 slide deck and the Ecosystem Documentation above.
#
# * Begin the design your robot classes here. You will develop your classes further to improve their functionality as you move through the stages.
#   There are three classes you need initially.
#   * Robot - _base_ or parent class
#   * Droid - inherits from Robot
#   * Drone - inherits from Robot
#
#   Interface requirements and recommendations for attributes (instance variables and methods) are documented above. See the stage 1 slide deck on Learn
#
#   * Tests - There are three code cells below for running test.
#
#   * Use
#
# **Robot Classes CRP Notes**
#
# **CRPs should augment code cells with text cells to document designs for third parties and assessment in your final submission. It's good practice to developing working text cells for this purpose from day 1

# %% [markdown]
# #**Robot Classes**
# Create you robot classes in the code cells below. Remember you will come back to these classes later to add methods and modify object behaviours. Read the suggested reading on inheritance.
#
# Don't _pollute_ you class code cells with testing code. Use test code cells beelow. Of course you can test as you go. But tidy it up, comment your code. Before your submission you can add text cells to discuss your approach to creating classes, particularly if you have applied advanced methods of inheritance using super() functions, and using decorators on your properties. Note however simple methods and properties are quite acceptable.

# %%
############################################
# @title Robot Class [code] {display-mode: "code"} 
############################################

#Design your robot class here. 

class Robot:                          #Creating a Robot class
  def __init__(self, name):
    self.coordinates = [0, 0, 0]      #Assigning instance variables
    self.status = 'on'
    self.kind = 'Robot'
    self.max = [1, 1, 0]
    self.velocity = [0, 0, 0]
    self.activity = 'idle'
    self.name = name
    self.age = 0
    self.serviced = 0
    self.soc = 600
    self.capacity = 600
    self.service = 0
    self.damage = 0
    self.target = None
    self.payload = 100
    self.cargo = None
    self.station = None
    self.distance = 0
    self.energy = 0
    self.active = 0
  


  def move(self):

        if self.kind == 'Drone':
          if self.coordinates[0:2] == self.target[0:2] and self.coordinates[2] != self.target[2]:          #If the x and y coords are equal to the target but z is not, equal the z coord to the target z coord            
            self.coordinates[2] = self.target[2]
          if self.coordinates[0:2] != self.target[0:2] and self.coordinates[2] == 0:                   #If x and y coords are not equal to the target and z is 0, set z to 1 so that it can move
            self.coordinates[2] = 1
          if self.coordinates[0:2] != self.target[0:2] and self.coordinates[2] == 1:                   #Setting the z velocity to 0 if the z coord is already 1 and x and y is not equal to the target
            self.velocity[2] = 0

        for i in [0, 1]:
          if self.coordinates[i] <  self.target[i]:                          #Setting the velocity when the robot is below the target
            if self.max[i] > abs(self.target[i] - self.coordinates[i]):     #Change from max velocity to the maximum needed for a move if it goes beyond the target point
              self.velocity[i] =  self.target[i] - self.coordinates[i]     
            else:
              self.velocity[i] = self.max[i]                                 #Setting velocity to max if the max velocity is the same as the final move to the target

          elif self.coordinates[i] >  self.target[i]:                        #Setting velocity if the robot is above the target 
            if self.max[i] > abs(self.coordinates[i] - self.target[i]):      
              self.velocity[i] = self.target[i] - self.coordinates[i]
            else:
              self.velocity[i] = -self.max[i]                                #Setting velocity to negative max if the max velocity is the same as the final move to the target 

          else:
            self.velocity[i] = 0                                             #Set velocity to 0 when robot's coordinates are the same as the target coordinates
          self.coordinates[i] += self.velocity[i]                            #Increment the velocity everytime it goes through the loop
   
  
         
         #ecosystem.x_max



        if self.coordinates[0] == self.target[0]:                     #Set the x velocity to 0 if the robot x coordinate equals the target x coordinate
            self.velocity[0] = 0
        if self.coordinates[1] == self.target[1]:                     #Set the y velocity to 0 if the robot y coordinate equals the target y coordinate
            self.velocity[1] = 0  
        if self.coordinates[2] == self.target[2]:                     #Set the z velocity to 0 if the robot z coordinate equals the target x coordinate
            self.velocity[2] = 0

# %%
#43 elif self.max[1] > abs(self.target[1]) - abs(self.coordinates[1]):        #Change from max velocity for a move if it goes beyond the target point
          #self.coordinates[1] +=  abs(self.target[1]) - abs(self.coordinates[1])

# %%
############################################
# @title Droid Class [code] {display-mode: "code"} 
############################################

#Design your droid class here. 

class Droid(Robot):              #Creating a child class from the Robot class
  def __init__(self, name):
    super().__init__(name)       #Inheriting all the methods and attributes of the parent class
    self.kind = 'Droid'          #Overriding the instance variables of the parent class
    self.max = [2, 2, 0]
    self.soc = 2000
    self.capacity = 2000
    self.size = 400
    self.payload = 200

# %%
############################################
# @title Drone Class [code] {display-mode: "code"} 
############################################

#Design your drone class here. 

class Drone(Robot):            #Creating a child class from the Robot class
  def __init__(self, name):
    super().__init__(name)     #Inheriting all the methods and attributes of the parent class
    self.kind = 'Drone'        #Overriding the instance variables of the parent class
    self.max = [3, 3, 1]
    self.soc = 500
    self.capacity = 500
    self.size = 600
    self.payload = 50

# %% [markdown]
# ## **Stage 1 Testing**
#
# There are 3 exercises in this section
#
# 1. Test 1 Instantiation
# 2. Test 2 Attributes Zone
# 3. Test 3 -Robot Factory
#
# Use the code cells below to test your robot classes. You should ensure:
#
# * Your robots, droids and drones classes instantiate without any error
# * Instantiate an ecosystem, register robots and and display them.
#
# See the slide deck for stage 1 for more information. Make sure you follow the ecosystem training. Note that automatic code testing will check your robots can perform as suggested in these test cells

# %%
##############################################################
# @title Test 1 Instantiation [code] {display-mode: "code"} 
##############################################################
#Test 1.
#Instantiate your robots so that they appear in random places when you execute an ecosystem display.
#Test some ecosystem properties such as messages, deregister, count_operational

ecosystem = Ecosystem()              #Instantiating ecosystem class
ecosystem.display_on_update = True   #Display is updated when the ecosystem updates

robot = Robot('Roboium')             #Instantiating Robot class
ecosystem.register(robot)            #Registering robot into the ecosystem

droid = Droid('Droium')              #Instantiating Droid class
ecosystem.register(droid)            #Registering droid into the ecosystem

drone = Drone('Dronium')             #Instantiating Drone class
ecosystem.register(drone)            #Registering drone into the ecosystem


ecosystem.display()

print(ecosystem.messages)
print('Robots registration dictionary:', ecosystem.robot_register)
print('List of robots:', ecosystem.robots)
# Out:
# info       Robot    140274323677776  register Robot registered with 0 damage points
# info       Droid    140274323677520  register Droid registered with 0 damage points
# info       Drone    140274323677584  register Drone registered with 0 damage points
#
# Robots registration dictionary: {140274323677776: {'kind': 'Robot', 'coordinates': [36, 27, 0], 'max': [1, 1, 0], 'velocity': [0, 0, 0], 'status': 'on', 'activity': 'idle', 'name': 'Roboium', 'target': None, 'age': 0, 'active': 0, 'serviced': 0, 'soc': 600, 'capacity': 600, 'service': 0, 'damage': 0, 'on_arena': 0, 'shape': 'square', 'color': 'blue', 'size': 250, 'alpha': 1, 'weight': 50, 'payload': 100, 'cargo': None, 'station': None, 'distance': 0, 'energy': 0, 'kind_class': 'Robot'}, 140274323677520: {'kind': 'Droid', 'coordinates': [48, 5, 0], 'max': [2, 2, 0], 'velocity': [0, 0, 0], 'status': 'on', 'activity': 'idle', 'name': 'Droium', 'target': None, 'age': 0, 'active': 0, 'serviced': 0, 'soc': 2000, 'capacity': 2000, 'service': 0, 'damage': 0, 'on_arena': 0, 'shape': 'circle', 'color': 'red', 'size': 400, 'alpha': 1, 'weight': 100, 'payload': 200, 'cargo': None, 'station': None, 'distance': 0, 'energy': 0, 'kind_class': 'Robot'}, 140274323677584: {'kind': 'Drone', 'coordinates': [28, 11, 0], 'max': [3, 3, 1], 'velocity': [0, 0, 0], 'status': 'on', 'activity': 'idle', 'name': 'Dronium', 'target': None, 'age': 0, 'active': 0, 'serviced': 0, 'soc': 500, 'capacity': 500, 'service': 0, 'damage': 0, 'on_arena': 0, 'shape': 'triangle', 'color': 'green', 'size': 600, 'alpha': 1, 'weight': 25, 'payload': 50, 'cargo': None, 'station': None, 'distance': 0, 'energy': 0, 'kind_class': 'Robot'}}
# List of robots: [<__main__.Robot object at 0x7f94293be250>, <__main__.Droid object at 0x7f94293be150>, <__main__.Drone object at 0x7f94293be190>]

# %%
##############################################################
# @title Test 2 Attributes Zone [code] {display-mode: "code"} 
##############################################################
#Test 2
#Instantiate robots and change attributes. 
# Demonstrate your awareness of robot attributes such as size, colour and shape


ecosystem = Ecosystem()
ecosystem.display_on_update = True

robot = Robot('Roboium')             #Calling the robot classes
droid = Droid('Droium')              
drone = Drone('Dronium')             

#Changing attributes which are not read only

robot.coordinates = [10,25,0]        #Changing coordinate values from the defualt positioning
droid.coordinates = [15,20,0]
drone.coordinates = [25,15,1]

robot.velocity = [1,1,0]             #Changing velocity values from the default velocity
droid.velocity = [2,2,0]
drone.velocity = [3,3,1]

robot.shape = 'circle'               #Changing other attributes from their default
droid.color = 'green'                  
drone.size = 650


robot.max = [0,0,0]                  #Changing read only attributes will give errors leading to damage
droid.soc = 3000
drone.capacity =2000               

ecosystem.register(robot,droid,drone)

ecosystem.display_parameters['title'] = 'Number of robots:' + str(ecosystem.count_operational)
ecosystem.display_parameters['annotations'] = ['max','soc','damage']
ecosystem.display()
print(ecosystem.messages)
# Out:
# damage     Robot    140274323329744  register 'max' error: Value '[0, 0, 0]' rejected. Cannot be changed from '[1, 1, 0]'. Set to [1, 1, 0].
# info       Robot    140274323329744  register Robot registered with 1 damage points
# damage     Droid    140274323329296  register 'soc' error: Value '3000' rejected. Cannot be changed from '2000'. Set to 2000.
# info       Droid    140274323329296  register Droid registered with 1 damage points
# damage     Drone    140274323329808  register 'capacity' error: Value '2000' rejected. Cannot be changed from '500'. Set to 500.
# info       Drone    140274323329808  register Drone registered with 1 damage points

# %%
##############################################################
# @title Test 3 -Robot Factory [code] {display-mode: "code"} 
##############################################################
#Test 3
#Instantiate at least a dozen robots in a loop.
# It is up to you how you arrange them - random or otherwise

ecosystem = Ecosystem()
ecosystem.display_on_update = True

robotList=[]

for i in range(12):
  robots = randint(0,11)
  if robots in range(0,3):
    robotList.append(Robot('robot' + str(i)))
  elif robots in range(4,7):
    robotList.append(Droid('droid' + str(i)))
  else:
    robotList.append(Drone('drone' + str(i)))

for i in robotList:
  ecosystem.register(i)
  ecosystem.update()
  ecosystem.display()

# %% [markdown]
# ### **Preparation for Movement**
#
# If you finish the above begin to design a move  method which changes the ```coordinates``` of a robot. The method should respect the configuration of ```velocity``` (3 vectors, positive or negetive), the maximum **absolute** values of the permitted velocity given by ```max```. Any changes to coordinates, and the system boundary. See the Robot Methods section in Robot Documentation.
#
# Use your classes above! Your refactoring of the classes work should not break previous tests

# %%
##############################################################
# @title - Robot Targets and Moving [code] {display-mode: "code"} 
##############################################################
#This section not assessed
#Begin to think about furnishing your robot with a move method and target coordinates.

ecosystem = Ecosystem()
ecosystem.display_on_update = True



ecosystem.display
# Out:
# <bound method Ecosystem.display of <__main__.Ecosystem object at 0x7f94293bee90>>

# %% [markdown]
# # **Stage 2 - Training and Development**
#
# There are seven exercises in this section.
#
# Some are simple adaptations of the previous, so copy your code forwards.
# Create a new ecosystem for each exercise so it is independent of previous code cells.
#
#
# This section principally involves the development of 'methods' for your robot.
#
# Methods should be fully developed for the parent Robot class, and Droids and Drones should **inherit** these methods. However you should ensure that subtle differences in their attribute values should be respected by the method so that it works correctly for each type of Robot.
#
# 1. Creating Pizzas
# 1. Target and Move
# 1. Deliveree
# 1. Work Till You Drop
# 1. Factoree Deliveree
# 1. Charger
# 1. Factory Delivery and Charging
#
#
# **Please see slide deck on Stage 2 for guidance on these exercises.**
#
#
#
#
#
#
#
#
#
# ---

# %%
##############################################################
# @title Creating Pizzas [code] {display-mode: "code"} 
##############################################################
#Instantiate an Ecosystem and test the creation of Pizzas. 
#Make sure you assign your pizza to a variable.
#Explore and comment on the properties of your pizza: coordinates, weight, target.
#Note, there is no cheese.

ecosystem = Ecosystem()
ecosystem.display_on_update = True

piz1 = ecosystem.create('Pizza')      #Creating a pizza object
piz2 = ecosystem.create('Pizza')


ecosystem.display()

print('piz1 coordinates:',piz1.coordinates)     #Location of piz1
print('piz2 mass:',piz2.weight, 'kg')           #Mass in kg of piz2
print('piz2 target:',piz2.target)               #The place where the pizza is to be delivered
# Out:
# piz1 coordinates: [7, 10, 0]
# piz2 mass: 50 kg
# piz2 target: [48, 1, 0]

# %%
##############################################################
# @title Target and Move [code] {display-mode: "code"} 
##############################################################
# Deliver this test code cell  for your working move method
# Instantiate an Ecosystem, create a pizza and assign to a variable.
# Create a Robot, and set the target to the pizza co-ordinates.
# Use the Loop Pattern (slide 9), call move() and update(). 
# A well behaved robot should get to the the pizza. 
# Your move method should work for all three kinds of robot.


ecosystem = Ecosystem()
ecosystem.display_on_update = True
ecosystem.duration = 100

piz3 = ecosystem.create('Pizza')     #Creating a pizza

robot = Robot('Robum')             #Instantiating Robot class
ecosystem.register(robot)      

robot.target = piz3.coordinates    #Assigning the target(pizza) coordinates to the robot

while ecosystem.stop == False and robot.coordinates != piz3.coordinates:                  #When the number of hours is less than the duration and the robot's location is not the same as the pizza's location
  robot.move()
  ecosystem.update()
 

print(piz3.coordinates)
print(robot.coordinates)
print(robot.soc)

print(ecosystem.messages)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-1eeedb0e5fea> in <module>()
#      23 while ecosystem.stop == False and robot.coordinates != piz3.coordinates:                  #When the number of hours is less than the duration and the robot's location is not the same as the pizza's location
#      24   robot.move()
# ---> 25   ecosystem.update()
#      26
#      27
#
# <ipython-input-13-eb2e530a49f7> in update(self)
#     359     self._hour += 1
#     360     if self.display_on_update:
# --> 361       self.display()
#     362
#
# <ipython-input-13-eb2e530a49f7> in display(self)
#     149           self.display_parameters[attribute] = getattr(self, attribute,'#error#')
#     150           print (attribute, self.display_parameters[attribute] , getattr(self, attribute,'#error#'))
# --> 151     display(markers, **self.display_parameters)
#     152
#     153 ##   MARKERS       ##
#
# <ipython-input-11-7687d83e61ac> in display(markers, **kwargs)
#      74   ax.grid(color = 'red', linestyle = '--', linewidth = 0.25)
#      75
# ---> 76   plt.show()
#      77   time.sleep(pause/1000)
#      78
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in show(*args, **kw)
#     270     """
#     271     global _show
# --> 272     return _show(*args, **kw)
#     273
#     274
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/display.py in display(*objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     171             md = None
#     172             try:
# --> 173                 data = formatter(obj)
#     174             except:
#     175                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     215     """show traceback on failed format call"""
#     216     try:
# --> 217         r = method(self, *args, **kwargs)
#     218     except NotImplementedError:
#     219         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2098                            else suppress())
#    2099                     with ctx:
# -> 2100                         self.figure.draw(renderer)
#    2101                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2102                     bbox_inches = self.figure.get_tightbbox(renderer,
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1734             self.patch.draw(renderer)
#    1735             mimage._draw_list_compositing_images(
# -> 1736                 renderer, self, artists, self.suppressComposite)
#    1737
#    1738             renderer.close_group('figure')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2628             renderer.stop_rasterizing()
#    2629
# -> 2630         mimage._draw_list_compositing_images(renderer, self, artists)
#    2631
#    2632         renderer.close_group('axes')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1227         ticks_to_draw = self._update_ticks()
#    1228         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
# -> 1229                                                                 renderer)
#    1230
#    1231         for tick in ticks_to_draw:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1172         """Return lists of bboxes for ticks' label1's and label2's."""
#    1173         return ([tick.label1.get_window_extent(renderer)
# -> 1174                  for tick in ticks if tick.label1.get_visible()],
#    1175                 [tick.label2.get_window_extent(renderer)
#    1176                  for tick in ticks if tick.label2.get_visible()])
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axis.py in <listcomp>(.0)
#    1172         """Return lists of bboxes for ticks' label1's and label2's."""
#    1173         return ([tick.label1.get_window_extent(renderer)
# -> 1174                  for tick in ticks if tick.label1.get_visible()],
#    1175                 [tick.label2.get_window_extent(renderer)
#    1176                  for tick in ticks if tick.label2.get_visible()])
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     903             raise RuntimeError('Cannot get window extent w/o renderer')
#     904
# --> 905         bbox, info, descent = self._get_layout(self._renderer)
#     906         x, y = self.get_unitless_position()
#     907         x, y = self.get_transform().transform((x, y))
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/text.py in _get_layout(self, renderer)
#     353         # the corners of the unrotated bounding box
#     354         corners_horiz = np.array(
# --> 355             [(xmin, ymin), (xmin, ymax), (xmax, ymax), (xmax, ymin)])
#     356
#     357         # now rotate the bbox
#
# KeyboardInterrupt:

# %%
#droid
ecosystem = Ecosystem()
ecosystem.display_on_update = True
ecosystem.duration = 100

piz3 = ecosystem.create('Pizza')     #Creating a pizza

droid = Droid('Robum')             #Instantiating Robot class
ecosystem.register(droid)      

droid.target = piz3.coordinates    #Assigning the target(pizza) coordinates to the robot

while ecosystem.stop == False and droid.coordinates != piz3.coordinates:
  droid.move()
  ecosystem.update()
 

print(piz3.coordinates)
print(droid.coordinates)
print(droid.soc)

print(ecosystem.messages)

# %%
ecosystem = Ecosystem()
ecosystem.display_on_update = True
ecosystem.duration = 30

piz3 = ecosystem.create('Pizza')     #Creating a pizza

drone = Drone('Robum')             #Instantiating Robot class
ecosystem.register(drone)      

drone.target = piz3.coordinates    #Assigning the target(pizza) coordinates to the robot

while ecosystem.stop == False and drone.coordinates != piz3.coordinates:
  drone.move()
  ecosystem.update()
 

print(piz3.coordinates)
print(drone.coordinates)
print(drone.soc)

print(ecosystem.messages)

# %%
##############################################################
# @title Deliveree [code] {display-mode: "code"} 
##############################################################
# Deliver a delivery code cell. 
# A registered robot enters the loop and is avialable to deliver pizza.
# When delivered move the robot off the pizza and becomes idle. 
# End the loop using the ecosystems count_operational attribute.
# Tip - use the Robot 'busy' activity to move off, but not be given another pizza!


ecosystem = Ecosystem()
ecosystem.display_on_update = True
ecosystem.duration = 100
ecosystem.display_parameters['title'] = 'Pick up and drop'
ecosystem.display_parameters['annotations'] = ['max','soc','activity']

robut = Robot('robut')                   #Instantiating a robot
ecosystem.register(robut)
robut.activity = 'available'             #Setting robot's actvity to make it available to deliver pizzas

while ecosystem.stop == False and ecosystem.count_operational !=0:
  if robut.activity == 'available':                                     
   pizza = ecosystem.create('Pizza')                                   #Creating a pizza if the robot is available
   robut.cargo = pizza                                                 #Adding pizza as the robot's cargo
   robut.activity = 'delivering'
  if robut.activity == 'delivering':
    if robut.cargo.status == 'awaiting_collection':                      
      robut.target = robut.cargo.coordinates  
      robut.move()                                            #Robot's destination is the cargo's location
    elif robut.cargo.status == 'in_transit':
      robut.target = robut.cargo.target
      robut.move()                                                   #Robot's destination is the cargo's target
    elif robut.cargo.status == 'delivered':
      robut.cargo = None
      if robut.cargo == None:
         robut.target = randcoordinates
         robut.move()    
         robut.activity = 'idle'   
         if robut.activity == 'idle':
           robut.velocity = 0
                                                            #The Robot has emptied its cargo
      
                                                                 #The robot is idling so will not deliver any pizza
  ecosystem.update()
  print(ecosystem.hour)

print(ecosystem.messages)
print(ecosystem.robot_register)

# %%
##############################################################
# @title Work Till You Drop [code] {display-mode: "code"} 
##############################################################
# This exercise is the same as deliveree, but the Robot becomes
# available again and is given a new pizza cargo. It works until it 
# it drops. End the loop gracefully using the count_operational attribute

ecosystem = Ecosystem()
ecosystem.display_on_update = True
ecosystem.duration = 200
ecosystem.display_parameters['title'] = 'Pick up and drop'
ecosystem.display_parameters['annotations'] = ['max','soc','activity']

robut = Robot('robut')
ecosystem.register(robut)
robut.activity = 'available'

while ecosystem.stop == False and ecosystem.count_operational !=0:
  if robut.activity == 'available':
    pizza = ecosystem.create('Pizza')
    robut.cargo = pizza
    robut.activity = 'delivering'
  if robut.activity == 'delivering':
    if robut.cargo.status == 'awaiting_collection':
      robut.target = robut.cargo.coordinates
      robut.move()
    elif robut.cargo.status == 'in_transit':
      robut.target = robut.cargo.target
      robut.move()
    elif robut.cargo.status == 'delivered':
      robut.cargo = None
      robut.activity = 'available'  
      robut.move() 
  ecosystem.update()
  print(ecosystem.hour)

print(ecosystem.messages)
print(ecosystem.robot_register)

# %%
##############################################################
# @title Factoree Deliveree [code] {display-mode: "code"} 
##############################################################
# Use the Robot Factory (slide 13) to create a large number of robots
# Convert your Loop Pattern to iterate through all registered robots.
# Each robots gets a pizza and delivers it. After delivery it becomes
# available again. And so it carries on. Work each robot till it drops 
# To iterate through all the robots.
# End the loop gracefully using the count_operational attribute


ecosystem = Ecosystem()
ecosystem.display_on_update = True
ecosystem.duration = 100


robotList=[]

for i in range(12):
  robots = randint(0,11)
  if robots in range(0,3):
    robotList.append(Robot('robot' + str(i)))
  elif robots in range(4,7):
    robotList.append(Droid('droid' + str(i)))
  else:
    robotList.append(Drone('drone' + str(i)))
    

for i in robotList:
  i.activity = 'available'
  ecosystem.register(i)

pizzaList = []

while ecosystem.stop == False and ecosystem.count_operational !=0:
  for i in robotList:
    if i.activity == 'available':
      pizzaList.append(ecosystem.create('Pizza'))
      i.cargo = pizzaList[-1]
      i.activity = 'delivering'
    if i.activity == 'delivering':
      if i.cargo.status == 'awaiting_collection':
        i.target = i.cargo.coordinates
        i.move()
      elif i.cargo.status == 'in_transit':
        i.target = i.cargo.target
        i.move()
      elif i.cargo.status == 'delivered':
        i.cargo = None
        i.activity = 'available'  
        i.move()
  ecosystem.update()
ecosystem.display()
print(ecosystem.hour)
print(ecosystem.messages)

# %%
##############################################################
# @title Charger [code] {display-mode: "code"} 
##############################################################
# Take a simple one robot scenario and a loop pattern.
# Implement a charging station
# Use a simple charging strategy the percentage SOC (soc/capacity) 
# Should the %SOC be different for each robot type.


ecosystem = Ecosystem()
ecosystem.display_on_update = True
ecosystem.duration = 200
ecosystem.display_parameters['title'] = 'Pick up and drop'
ecosystem.display_parameters['annotations'] = ['max','soc','activity']

robut = Robot('robut')
ecosystem.register(robut)
robut.activity = 'available'
charger = ecosystem.create('Grid_Charger', [40,20,0])

pizzaList = []

while ecosystem.stop == False and ecosystem.count_operational !=0:
  if robut.soc/robut.capacity <= 0.4:
    robut.activity = 'charging'
    robut.station = charger
    robut.target = robut.station.coordinates
    robut.move()
  if robut.soc/robut.capacity >= 0.8:
    robut.station = None
    if robut.cargo == None:
      robut.activity = 'available'
    else:
      robut.activity = 'delivering'
       
  if robut.activity == 'available':
    pizzaList.append( ecosystem.create('Pizza'))
    robut.cargo = pizzaList[-1]
    robut.activity = 'delivering'
  if robut.activity == 'delivering':
    if robut.cargo.status == 'awaiting_collection':
      robut.target = robut.cargo.coordinates
      robut.move()
    elif robut.cargo.status == 'in_transit':
      robut.target = robut.cargo.target
      robut.move()
    elif robut.cargo.status == 'delivered':
      robut.cargo = None
      robut.activity = 'available'  
      robut.move() 
  ecosystem.update()
  print(ecosystem.hour)

print(ecosystem.messages)
print(ecosystem.robot_register)

# %%
##############################################################
# @title Factory Delivery and Charging [code] {display-mode: "code"} 
##############################################################
# Implement a charging station(s) for a factory scenario
# Use a simple charging strategy based on %SOCt
# Can you get your ecosystem to keep going for a thousand hours.
# Do all the robots survive?


ecosystem = Ecosystem()
ecosystem.display_on_update = False
ecosystem.duration = 1000
ecosystem.display_parameters['title'] = 'Pick up, drop and charge - Operating robots: {operational} / '+ str(len(robotList)) +'| Current hour: {hour} / {duration}'
ecosystem.display_parameters['annotations'] = ['soc']


charger = ecosystem.create('Grid_Charger', [40,20,0])

robotList=[]

for i in range(12):
  robots = randint(0,11)
  if robots in range(0,3):
    robotList.append(Robot('robot' + str(i)))
  elif robots in range(4,7):
    robotList.append(Droid('droid' + str(i)))
  else:
    robotList.append(Drone('drone' + str(i)))
    

for i in robotList:
  i.activity = 'available'
  ecosystem.register(i)

pizzaList = []

while ecosystem.stop == False and ecosystem.count_operational !=0:
  for i in robotList:
    if i.soc/i.capacity <= 0.4:
      i.activity = 'charging'
      i.station = charger
      i.target = i.station.coordinates
      i.move()
    if i.soc/i.capacity >= 0.8:
      i.station = None
      if i.cargo == None:
        i.activity = 'available'
      else:
        i.activity = 'delivering'
    if i.activity == 'available':
      pizzaList.append(ecosystem.create('Pizza'))
      i.cargo = pizzaList[-1]
      i.activity = 'delivering'
    if i.activity == 'delivering':
      if i.cargo.status == 'awaiting_collection':
        i.target = i.cargo.coordinates
        i.move()
      elif i.cargo.status == 'in_transit':
        i.target = i.cargo.target
        i.move()
      elif i.cargo.status == 'delivered':
        i.cargo = None
        i.activity = 'available'  
        i.move()
  ecosystem.update()
ecosystem.display()
print(ecosystem.hour)
print(ecosystem.messages)

# %% [markdown]
# # **Stage 3 - Ecosystem Monitoring**
#
# Stage 3 is about extracting some numbers from your ecosystem of robots
#
# By now with completion of **Factory Delivery and Charging** you should have successful ecosystem runs for several hundred hours, even 1000.
# With at least 10 robots delivering and charging. You might be losing some along
# the way but don't worry about this.
#
# But how do we know what has quantitatively been done. What data has been created along the way?  There are five data points that are collected for each robot, which you will have seen in the attribute table:
#
#
# |required    |name       |default   |validation  |datatype    |description                             |
# |------------|-----------|----------|------------|------------|----------------------------------------|
# |recommended |service    |0         |Read Only   |integer     |service points accrued by robot         |
# |recommended |age        |0         |Read Only   |integer     |age of robot in hours                   |
# |recommended |active        |0         |Read Only   |integer     |age of robot in hours                   |
# |optional    |distance   |0         |Read Only   |float       |distance travelled by robot             |
# |optional    |energy     |0         |Read Only   |float       |energy consumed by robot                |
#
# For metrics, make sure that you have these attributes in your parent Robot class. The ecosystem maintains a record in the registry so the data is collected in any case.
#
# Using these values you can derive:
#
# * $$Average\ \ speed = \frac{distance}{active\ hours} \  (squares.hour^{-1})$$
#
# * $$Service\ \ rate = \frac{service}{active\ hours} \  (kg.hour^{-1})$$
#
# * $$Energy\ \ efficiency\ \  = \frac{Energy}{Service} (kWh.kg^{-1} $$
#
# * $$Average\ \ Power\ \  = \frac{Energy}{active\ hours}\ \ (kWh.hour^{-1} = kW)$$
#
# All the required values are in the registry so lets access that.
#
# For the exercises in this stage take a **copy** of your working **Factory Charging** code cell in stage 2. As with all your code cells this should start with its own ecosystem instantiation.

# %%
##############################################################
# @title Monitoring of Factory Delivery and Charging [code] {display-mode: "code"} 
##############################################################
'''
Take a fully working copy of your factory delivery and charging code cell
turn off automatic updating of the display.
Make sure you have automatic display on update turned to False: 
ecosystem.display_on_update = False
When you run the code cell you will see how quicky it runs. 
So allowing the duration to be a 1000 hours should have little consequence
'''
ecosystem = Ecosystem()
ecosystem.display_on_update = False
ecosystem.duration = 1000

#Operating robots - number of robots functioning over the total amount. Current hour is the current hour of the the display by the total amount it will go up to
ecosystem.display_parameters['title'] = 'Pick up, drop and charge - Operating robots: {operational} / '+ str(len(robotList)) +'| Current hour: {hour} / {duration}'
ecosystem.display_parameters['annotations'] = ['soc']


charger = ecosystem.create('Grid_Charger', [40,20,0])              #Creating a charger in the ecosystem to power the robots back up 

robotList=[]                                                       #A list for all the robots instantiated

for i in range(12):                                             #Setting a range 12 for i to iterate through
  robots = randint(0,11)                                        #Using the random integer to generate an integer while the loop repeats
  if robots in range(0,3):                                      #If the random integer is between 0 and 2 append to Robot class
    robotList.append(Robot('robot' + str(i)))
  elif robots in range(4,7):
    robotList.append(Droid('droid' + str(i)))
  else:
    robotList.append(Drone('drone' + str(i)))
    
for i in robotList:                            
  i.activity = 'available'                                     #Set robot activity to available when registered
  ecosystem.register(i)

pizzaList = []

while ecosystem.stop == False and ecosystem.count_operational !=0:
  for i in robotList:
    if i.kind == 'droid':                                           
      if i.soc/i.capacity <= 0.1:                                   #Setting %soc of droid to be lower as it has a much higher capacity than the drone and robot
        i.activity = 'charging'                                     #Setting the robot activity to charging when it goes below 10% of the charge capacity  
    else:                                                           
      if i.soc/i.capacity <= 0.4:                                   #Setting %soc of drone and robot to be 0.4 to allow it to have enough charge to return to the charger        
        i.activity = 'charging'
    
    #Assigning the charger to the robot
    if i.activity == 'charging':                                    #If robot is charging set the station to the charger and set the target to the station
      i.station = charger                                           
      i.target = i.station.coordinates
      i.move()

    ##Setting robot activity after charging has finished
    if i.soc/i.capacity >= 0.95:
      i.station = None                                              #Removing the assigned station from the robot once it %soc is above 95%
      if i.cargo == None:
        i.activity = 'available'                                    #Setting the activity of the robot to available if it had no cargo after charging 
      else:
        i.activity = 'delivering'                                   #Robot activity set to delivering if it had cargo after charging         
    
    #Creating pizzas and assigning cargo 
    if i.activity == 'available':
      pizzaList.append(ecosystem.create('Pizza'))                  #Creating and adding pizzas to a list every time the loop is run
      i.cargo = pizzaList[-1]                                      #The cargo of the robot is set to the latest pizza appended to the list                                                  
      i.activity = 'delivering'                                    #Robot is delivering once it has a cargo assigned
      
    #Setting robot targets depending on the activity of the pizza and robot
    if i.activity == 'delivering':
      if i.cargo.status == 'awaiting_collection':
        i.target = i.cargo.coordinates
        i.move()
      elif i.cargo.status == 'in_transit':
        i.target = i.cargo.target
        i.move()
      elif i.cargo.status == 'delivered':
        i.cargo = None                                               #Setting cargo to none when it has delivered so it can move off
        i.activity = 'available'                                     #Setting robot activity to available to allow it to go through the loop again
        i.move()                                                  
  ecosystem.update()
ecosystem.display()
print(ecosystem.hour)
print(ecosystem.messages)
# Out:
# 1001
# info       Grid_Charger 140274322327952  register Grid_Charger registered with 0 damage points
# info       Drone    140274322328144  register Drone registered with 0 damage points
# info       Drone    140274322329360  register Drone registered with 0 damage points
# info       Drone    140274315909968  register Drone registered with 0 damage points
# info       Drone    140274315910352  register Drone registered with 0 damage points
# info       Drone    140274328992400  register Drone registered with 0 damage points
# info       Robot    140274316113296  register Robot registered with 0 damage points
# info       Drone    140274316113104  register Drone registered with 0 damage points
# info       Drone    140274322275984  register Drone registered with 0 damage points
# info       Robot    140274314651728  register Robot registered with 0 damage points
# info       Drone    140274316112464  register Drone registered with 0 damage points
# info       Droid    140274314650192  register Droid registered with 0 damage points
# info       Drone    140274314653200  register Drone registered with 0 damage points
# info       Pizza    140274314651984  register Pizza registered with 0 damage points
# info       Pizza    140274314652176  register Pizza registered with 0 damage points
# info       Pizza    140274314651408  register Pizza registered with 0 damage points
# info       Pizza    140274314650832  register Pizza registered with 0 damage points
# info       Pizza    140274312132752  register Pizza registered with 0 damage points
# info       Pizza    140274312131920  register Pizza registered with 0 damage points
# info       Pizza    140274312132560  register Pizza registered with 0 damage points
# info       Pizza    140274312131408  register Pizza registered with 0 damage points
# info       Pizza    140274312131472  register Pizza registered with 0 damage points
# info       Pizza    140274311517840  register Pizza registered with 0 damage points
# info       Pizza    140274312130960  register Pizza registered with 0 damage points
# info       Pizza    140274312133648  register Pizza registered with 0 damage points
# info       Pizza    140274320406864  register Pizza registered with 0 damage points
# info       Pizza    140274317701200  register Pizza registered with 0 damage points
# info       Pizza    140274322102160  register Pizza registered with 0 damage points
# info       Pizza    140274289891664  register Pizza registered with 0 damage points
# info       Pizza    140274431804880  register Pizza registered with 0 damage points
# info       Pizza    140274317637648  register Pizza registered with 0 damage points
# info       Pizza    140274310429328  register Pizza registered with 0 damage points
# info       Pizza    140274310427280  register Pizza registered with 0 damage points
# info       Pizza    140274320359632  register Pizza registered with 0 damage points
# info       Pizza    140274320359696  register Pizza registered with 0 damage points
# info       Pizza    140274394149392  register Pizza registered with 0 damage points
# info       Pizza    140274320359760  register Pizza registered with 0 damage points
# info       Pizza    140274320359888  register Pizza registered with 0 damage points
# info       Pizza    140274320361168  register Pizza registered with 0 damage points
# info       Pizza    140274425954384  register Pizza registered with 0 damage points
# info       Pizza    140274425955664  register Pizza registered with 0 damage points
# info       Pizza    140274425955152  register Pizza registered with 0 damage points
# info       Pizza    140274425954960  register Pizza registered with 0 damage points
# info       Pizza    140274329683472  register Pizza registered with 0 damage points
# info       Pizza    140274329685008  register Pizza registered with 0 damage points
# info       Pizza    140274329683280  register Pizza registered with 0 damage points
# info       Pizza    140274329685456  register Pizza registered with 0 damage points
# info       Pizza    140274329685200  register Pizza registered with 0 damage points
# info       Pizza    140274329683856  register Pizza registered with 0 damage points
# info       Pizza    140274329683600  register Pizza registered with 0 damage points
# info       Pizza    140274329682192  register Pizza registered with 0 damage points
# info       Pizza    140274329683920  register Pizza registered with 0 damage points
# info       Pizza    140274329683728  register Pizza registered with 0 damage points
# info       Pizza    140274329684368  register Pizza registered with 0 damage points
# info       Pizza    140274310672720  register Pizza registered with 0 damage points
# info       Pizza    140274329683216  register Pizza registered with 0 damage points
# info       Pizza    140274329682256  register Pizza registered with 0 damage points
# info       Pizza    140274329682320  register Pizza registered with 0 damage points
# info       Pizza    140274321798736  register Pizza registered with 0 damage points
# info       Pizza    140274318642704  register Pizza registered with 0 damage points
# info       Pizza    140274318643152  register Pizza registered with 0 damage points
# info       Pizza    140274311936208  register Pizza registered with 0 damage points
# info       Pizza    140274311935760  register Pizza registered with 0 damage points
# info       Pizza    140274311935952  register Pizza registered with 0 damage points
# info       Pizza    140274311936400  register Pizza registered with 0 damage points
# info       Pizza    140274311934352  register Pizza registered with 0 damage points
# info       Pizza    140274324099280  register Pizza registered with 0 damage points
# info       Pizza    140274324101456  register Pizza registered with 0 damage points
# info       Pizza    140274308292368  register Pizza registered with 0 damage points
# info       Pizza    140274308291984  register Pizza registered with 0 damage points
# info       Pizza    140274308289616  register Pizza registered with 0 damage points
# info       Pizza    140274308291152  register Pizza registered with 0 damage points
# info       Pizza    140274308290576  register Pizza registered with 0 damage points
# info       Pizza    140274308288720  register Pizza registered with 0 damage points
# info       Pizza    140274308289552  register Pizza registered with 0 damage points
# info       Pizza    140274308291536  register Pizza registered with 0 damage points
# info       Pizza    140274308292240  register Pizza registered with 0 damage points
# info       Pizza    140274308291920  register Pizza registered with 0 damage points
# info       Pizza    140274308290000  register Pizza registered with 0 damage points
# info       Pizza    140274308291856  register Pizza registered with 0 damage points
# info       Pizza    140274308290320  register Pizza registered with 0 damage points
# info       Pizza    140274308289680  register Pizza registered with 0 damage points
# info       Pizza    140274308289424  register Pizza registered with 0 damage points
# info       Pizza    140274308290512  register Pizza registered with 0 damage points
# info       Pizza    140274308291088  register Pizza registered with 0 damage points
# info       Pizza    140274308289808  register Pizza registered with 0 damage points
# info       Pizza    140274308289296  register Pizza registered with 0 damage points
# info       Pizza    140274308288912  register Pizza registered with 0 damage points
# info       Pizza    140274308289232  register Pizza registered with 0 damage points
# info       Pizza    140274308288848  register Pizza registered with 0 damage points
# info       Pizza    140274308290064  register Pizza registered with 0 damage points
# info       Pizza    140274308288784  register Pizza registered with 0 damage points
# info       Pizza    140274308289744  register Pizza registered with 0 damage points
# info       Pizza    140274308292560  register Pizza registered with 0 damage points
# info       Pizza    140274308289488  register Pizza registered with 0 damage points
# info       Pizza    140274308290448  register Pizza registered with 0 damage points
# info       Pizza    140274308290128  register Pizza registered with 0 damage points
# info       Pizza    140274308290768  register Pizza registered with 0 damage points
# info       Pizza    140274308291728  register Pizza registered with 0 damage points
# info       Pizza    140274308292432  register Pizza registered with 0 damage points
# info       Pizza    140274308290832  register Pizza registered with 0 damage points
# info       Pizza    140274308290896  register Pizza registered with 0 damage points
# info       Pizza    140274308291024  register Pizza registered with 0 damage points
# info       Pizza    140274308290256  register Pizza registered with 0 damage points
# info       Pizza    140274308292048  register Pizza registered with 0 damage points
# info       Pizza    140274308289040  register Pizza registered with 0 damage points
# info       Pizza    140274308291344  register Pizza registered with 0 damage points
# info       Pizza    140274308288592  register Pizza registered with 0 damage points
# info       Pizza    140274308290384  register Pizza registered with 0 damage points
# info       Pizza    140274308292112  register Pizza registered with 0 damage points
# info       Pizza    140274308290704  register Pizza registered with 0 damage points
# info       Pizza    140274308291280  register Pizza registered with 0 damage points
# info       Pizza    140274308289936  register Pizza registered with 0 damage points
# info       Pizza    140274308289360  register Pizza registered with 0 damage points
# info       Pizza    140274308291792  register Pizza registered with 0 damage points
# info       Pizza    140274308291408  register Pizza registered with 0 damage points
# info       Pizza    140274308289104  register Pizza registered with 0 damage points
# info       Pizza    140274308290640  register Pizza registered with 0 damage points
# info       Pizza    140274308289872  register Pizza registered with 0 damage points
# info       Pizza    140274308291664  register Pizza registered with 0 damage points
# info       Pizza    140274308292496  register Pizza registered with 0 damage points
# info       Pizza    140274308288976  register Pizza registered with 0 damage points
# info       Pizza    140274308288656  register Pizza registered with 0 damage points
# info       Pizza    140274308291472  register Pizza registered with 0 damage points
# info       Pizza    140274308291216  register Pizza registered with 0 damage points
# info       Pizza    140274308289168  register Pizza registered with 0 damage points
# info       Pizza    140274308292176  register Pizza registered with 0 damage points
# info       Pizza    140274308292304  register Pizza registered with 0 damage points
# info       Pizza    140274308291600  register Pizza registered with 0 damage points
# info       Pizza    140274308290960  register Pizza registered with 0 damage points
# info       Pizza    140274323314640  register Pizza registered with 0 damage points
# info       Pizza    140274323315728  register Pizza registered with 0 damage points
# info       Pizza    140274323393744  register Pizza registered with 0 damage points
# info       Pizza    140274323392080  register Pizza registered with 0 damage points
# info       Pizza    140274323392720  register Pizza registered with 0 damage points
# info       Pizza    140274321480720  register Pizza registered with 0 damage points
# info       Pizza    140274321479888  register Pizza registered with 0 damage points
# info       Pizza    140274321480784  register Pizza registered with 0 damage points
# info       Pizza    140274321480272  register Pizza registered with 0 damage points
# info       Pizza    140274322325712  register Pizza registered with 0 damage points
# info       Pizza    140274315878992  register Pizza registered with 0 damage points
# info       Pizza    140274315879440  register Pizza registered with 0 damage points
# info       Pizza    140274315880080  register Pizza registered with 0 damage points
# info       Pizza    140274315880336  register Pizza registered with 0 damage points
# info       Pizza    140274315878800  register Pizza registered with 0 damage points
# info       Pizza    140274315879760  register Pizza registered with 0 damage points
# info       Pizza    140274315881296  register Pizza registered with 0 damage points
# info       Pizza    140274315881808  register Pizza registered with 0 damage points
# info       Pizza    140274315882320  register Pizza registered with 0 damage points
# info       Pizza    140274315880016  register Pizza registered with 0 damage points
# info       Pizza    140274315879568  register Pizza registered with 0 damage points
# info       Pizza    140274315878928  register Pizza registered with 0 damage points
# info       Pizza    140274315880464  register Pizza registered with 0 damage points
# info       Pizza    140274315878608  register Pizza registered with 0 damage points
# info       Pizza    140274315882064  register Pizza registered with 0 damage points
# info       Pizza    140274315880784  register Pizza registered with 0 damage points
# info       Pizza    140274315882000  register Pizza registered with 0 damage points
# info       Pizza    140274315881104  register Pizza registered with 0 damage points
# info       Pizza    140274315879184  register Pizza registered with 0 damage points
# info       Pizza    140274315881040  register Pizza registered with 0 damage points
# info       Pizza    140274315880848  register Pizza registered with 0 damage points
# info       Pizza    140274315880144  register Pizza registered with 0 damage points
# info       Pizza    140274315880272  register Pizza registered with 0 damage points
# info       Pizza    140274315881872  register Pizza registered with 0 damage points
# info       Pizza    140274315881424  register Pizza registered with 0 damage points
# info       Pizza    140274315878544  register Pizza registered with 0 damage points
# info       Pizza    140274315882128  register Pizza registered with 0 damage points
# info       Pizza    140274315882384  register Pizza registered with 0 damage points
# info       Pizza    140274315879312  register Pizza registered with 0 damage points
# info       Pizza    140274315880208  register Pizza registered with 0 damage points
# info       Pizza    140274315880656  register Pizza registered with 0 damage points
# info       Pizza    140274315881360  register Pizza registered with 0 damage points
# info       Pizza    140274315878480  register Pizza registered with 0 damage points
# info       Pizza    140274315879696  register Pizza registered with 0 damage points
# info       Pizza    140274315880912  register Pizza registered with 0 damage points
# info       Pizza    140274315881936  register Pizza registered with 0 damage points
# info       Pizza    140274315880720  register Pizza registered with 0 damage points
# info       Pizza    140274315882192  register Pizza registered with 0 damage points
# info       Pizza    140274315880400  register Pizza registered with 0 damage points
# info       Pizza    140274315878672  register Pizza registered with 0 damage points
# info       Pizza    140274315878864  register Pizza registered with 0 damage points
# info       Pizza    140274315879248  register Pizza registered with 0 damage points
# info       Pizza    140274315882448  register Pizza registered with 0 damage points
# info       Pizza    140274315879376  register Pizza registered with 0 damage points
# info       Pizza    140274315878736  register Pizza registered with 0 damage points
# info       Pizza    140274315881232  register Pizza registered with 0 damage points
# info       Pizza    140274315879952  register Pizza registered with 0 damage points
# info       Pizza    140274315879824  register Pizza registered with 0 damage points
# info       Pizza    140274315881744  register Pizza registered with 0 damage points
# info       Pizza    140274328990224  register Pizza registered with 0 damage points
# info       Pizza    140274320804112  register Pizza registered with 0 damage points
# info       Pizza    140274320803472  register Pizza registered with 0 damage points
# info       Pizza    140274328959248  register Pizza registered with 0 damage points
# info       Pizza    140274311844112  register Pizza registered with 0 damage points
# info       Pizza    140274311847120  register Pizza registered with 0 damage points
# info       Pizza    140274311844432  register Pizza registered with 0 damage points
# info       Pizza    140274311844880  register Pizza registered with 0 damage points
# info       Pizza    140274311843984  register Pizza registered with 0 damage points
# info       Pizza    140274311845008  register Pizza registered with 0 damage points
# info       Pizza    140274311845520  register Pizza registered with 0 damage points
# info       Pizza    140274311845328  register Pizza registered with 0 damage points
# info       Pizza    140274311844560  register Pizza registered with 0 damage points
# info       Pizza    140274322328720  register Pizza registered with 0 damage points
# info       Pizza    140274322328784  register Pizza registered with 0 damage points
# info       Pizza    140274321087952  register Pizza registered with 0 damage points
# info       Pizza    140274313802896  register Pizza registered with 0 damage points
# info       Pizza    140274313803472  register Pizza registered with 0 damage points
# info       Pizza    140274425940368  register Pizza registered with 0 damage points
# info       Pizza    140274315846032  register Pizza registered with 0 damage points
# info       Pizza    140274315848656  register Pizza registered with 0 damage points
# info       Pizza    140274315848848  register Pizza registered with 0 damage points
# info       Pizza    140274316399376  register Pizza registered with 0 damage points
# info       Pizza    140274316401936  register Pizza registered with 0 damage points
# info       Pizza    140274316402192  register Pizza registered with 0 damage points
# info       Pizza    140274314274128  register Pizza registered with 0 damage points
# info       Pizza    140274314275152  register Pizza registered with 0 damage points
# info       Pizza    140274314274768  register Pizza registered with 0 damage points
# info       Pizza    140274314289360  register Pizza registered with 0 damage points
# info       Pizza    140274314290960  register Pizza registered with 0 damage points
# info       Pizza    140274329067344  register Pizza registered with 0 damage points
# info       Pizza    140274329066704  register Pizza registered with 0 damage points
# info       Pizza    140274329064848  register Pizza registered with 0 damage points
# info       Pizza    140274329065872  register Pizza registered with 0 damage points
# info       Pizza    140274329064720  register Pizza registered with 0 damage points
# info       Pizza    140274329066256  register Pizza registered with 0 damage points
# info       Pizza    140274329064912  register Pizza registered with 0 damage points
# info       Pizza    140274329064272  register Pizza registered with 0 damage points
# info       Pizza    140274329066384  register Pizza registered with 0 damage points
# info       Pizza    140274329066448  register Pizza registered with 0 damage points
# info       Pizza    140274329067408  register Pizza registered with 0 damage points
# info       Pizza    140274329065808  register Pizza registered with 0 damage points
# info       Pizza    140274318783504  register Pizza registered with 0 damage points
# info       Pizza    140274318785872  register Pizza registered with 0 damage points
# info       Pizza    140274307269456  register Pizza registered with 0 damage points
# info       Pizza    140274307269584  register Pizza registered with 0 damage points
# info       Pizza    140274307269712  register Pizza registered with 0 damage points
# info       Pizza    140274310648464  register Pizza registered with 0 damage points
# info       Pizza    140274310650384  register Pizza registered with 0 damage points
# info       Pizza    140274319876432  register Pizza registered with 0 damage points
# info       Pizza    140274310648272  register Pizza registered with 0 damage points
# info       Pizza    140274310648528  register Pizza registered with 0 damage points
# info       Pizza    140274310651664  register Pizza registered with 0 damage points
# info       Pizza    140274317803984  register Pizza registered with 0 damage points
# info       Pizza    140274317806800  register Pizza registered with 0 damage points
# info       Pizza    140274316395600  register Pizza registered with 0 damage points
# info       Pizza    140274316395536  register Pizza registered with 0 damage points
# info       Pizza    140274314650896  register Pizza registered with 0 damage points
# info       Pizza    140274314650960  register Pizza registered with 0 damage points
# info       Pizza    140274314653456  register Pizza registered with 0 damage points
# info       Pizza    140274314650448  register Pizza registered with 0 damage points
# info       Pizza    140274314652368  register Pizza registered with 0 damage points
# info       Pizza    140274314652048  register Pizza registered with 0 damage points
# info       Pizza    140274314652752  register Pizza registered with 0 damage points
# info       Pizza    140274314651088  register Pizza registered with 0 damage points
# info       Pizza    140274314651280  register Pizza registered with 0 damage points
# info       Pizza    140274314651216  register Pizza registered with 0 damage points
# info       Pizza    140274314652624  register Pizza registered with 0 damage points
# info       Pizza    140274314650512  register Pizza registered with 0 damage points
# info       Pizza    140274314652304  register Pizza registered with 0 damage points
# info       Pizza    140274314653328  register Pizza registered with 0 damage points
# info       Pizza    140274314652944  register Pizza registered with 0 damage points
# info       Pizza    140274314649872  register Pizza registered with 0 damage points
# info       Pizza    140274314652432  register Pizza registered with 0 damage points
# info       Pizza    140274314650320  register Pizza registered with 0 damage points
# info       Pizza    140274314653264  register Pizza registered with 0 damage points
# info       Pizza    140274314650000  register Pizza registered with 0 damage points
# info       Pizza    140274314651536  register Pizza registered with 0 damage points
# info       Pizza    140274314651792  register Pizza registered with 0 damage points
# info       Pizza    140274314651472  register Pizza registered with 0 damage points
# info       Pizza    140274314651664  register Pizza registered with 0 damage points
# info       Pizza    140274314651024  register Pizza registered with 0 damage points
# info       Pizza    140274314649936  register Pizza registered with 0 damage points
# info       Pizza    140274314652816  register Pizza registered with 0 damage points
# info       Pizza    140274314650768  register Pizza registered with 0 damage points
# info       Pizza    140274314653648  register Pizza registered with 0 damage points
# info       Pizza    140274314651152  register Pizza registered with 0 damage points
# info       Pizza    140274314653072  register Pizza registered with 0 damage points
# info       Pizza    140274314653392  register Pizza registered with 0 damage points
# info       Pizza    140274314650256  register Pizza registered with 0 damage points
# info       Pizza    140274316460368  register Pizza registered with 0 damage points
# info       Pizza    140274316462224  register Pizza registered with 0 damage points
# info       Pizza    140274309029328  register Pizza registered with 0 damage points
# info       Pizza    140274309026384  register Pizza registered with 0 damage points
# info       Pizza    140274317662224  register Pizza registered with 0 damage points
# info       Pizza    140274317662352  register Pizza registered with 0 damage points
# info       Pizza    140274317661136  register Pizza registered with 0 damage points
# info       Pizza    140274311518352  register Pizza registered with 0 damage points
# info       Pizza    140274311519184  register Pizza registered with 0 damage points
# info       Pizza    140274311519632  register Pizza registered with 0 damage points
# info       Pizza    140274311517200  register Pizza registered with 0 damage points
# info       Pizza    140274311517264  register Pizza registered with 0 damage points
# info       Pizza    140274311517392  register Pizza registered with 0 damage points
# info       Pizza    140274311520080  register Pizza registered with 0 damage points
# info       Pizza    140274311517328  register Pizza registered with 0 damage points
# info       Pizza    140274311519440  register Pizza registered with 0 damage points
# info       Pizza    140274311519760  register Pizza registered with 0 damage points
# info       Pizza    140274311519568  register Pizza registered with 0 damage points
# info       Pizza    140274311516368  register Pizza registered with 0 damage points
# info       Pizza    140274311516944  register Pizza registered with 0 damage points
# info       Pizza    140274311518736  register Pizza registered with 0 damage points
# info       Pizza    140274311520208  register Pizza registered with 0 damage points
# info       Pizza    140274311519824  register Pizza registered with 0 damage points
# info       Pizza    140274311518160  register Pizza registered with 0 damage points
# info       Pizza    140274311517904  register Pizza registered with 0 damage points
# info       Pizza    140274311516432  register Pizza registered with 0 damage points
# info       Pizza    140274311517072  register Pizza registered with 0 damage points
# info       Pizza    140274311518288  register Pizza registered with 0 damage points
# info       Pizza    140274311517584  register Pizza registered with 0 damage points
# info       Pizza    140274311518032  register Pizza registered with 0 damage points
# info       Pizza    140274311519696  register Pizza registered with 0 damage points
# info       Pizza    140274311516688  register Pizza registered with 0 damage points
# info       Pizza    140274311518608  register Pizza registered with 0 damage points
# info       Pizza    140274311517968  register Pizza registered with 0 damage points
# info       Pizza    140274311516496  register Pizza registered with 0 damage points
# info       Pizza    140274311519120  register Pizza registered with 0 damage points
# info       Pizza    140274311519056  register Pizza registered with 0 damage points
# info       Pizza    140274311516816  register Pizza registered with 0 damage points
# info       Pizza    140274312134096  register Pizza registered with 0 damage points
# info       Pizza    140274312133904  register Pizza registered with 0 damage points
# info       Pizza    140274312132432  register Pizza registered with 0 damage points
# info       Pizza    140274312133520  register Pizza registered with 0 damage points
# info       Pizza    140274312134544  register Pizza registered with 0 damage points
# info       Pizza    140274312133584  register Pizza registered with 0 damage points
# info       Pizza    140274312131600  register Pizza registered with 0 damage points
# info       Pizza    140274312130768  register Pizza registered with 0 damage points
# info       Pizza    140274312131344  register Pizza registered with 0 damage points
# info       Pizza    140274312132176  register Pizza registered with 0 damage points
# info       Pizza    140274312130640  register Pizza registered with 0 damage points
# info       Pizza    140274312132880  register Pizza registered with 0 damage points
# info       Pizza    140274312133200  register Pizza registered with 0 damage points
# info       Pizza    140274312130832  register Pizza registered with 0 damage points
# info       Pizza    140274312131216  register Pizza registered with 0 damage points
# info       Pizza    140274312132368  register Pizza registered with 0 damage points
# info       Pizza    140274312133392  register Pizza registered with 0 damage points
# info       Pizza    140274312133968  register Pizza registered with 0 damage points
# info       Pizza    140274312131728  register Pizza registered with 0 damage points
# info       Pizza    140274312133328  register Pizza registered with 0 damage points
# info       Pizza    140274312134288  register Pizza registered with 0 damage points
# info       Pizza    140274312132496  register Pizza registered with 0 damage points
# info       Pizza    140274312131280  register Pizza registered with 0 damage points
# info       Pizza    140274312132688  register Pizza registered with 0 damage points
# info       Pizza    140274312134160  register Pizza registered with 0 damage points
# info       Pizza    140274312132240  register Pizza registered with 0 damage points
# info       Pizza    140274312133072  register Pizza registered with 0 damage points
# info       Pizza    140274312134480  register Pizza registered with 0 damage points
# info       Pizza    140274312134416  register Pizza registered with 0 damage points
# info       Pizza    140274312131088  register Pizza registered with 0 damage points
# info       Pizza    140274312132624  register Pizza registered with 0 damage points
# info       Pizza    140274312131152  register Pizza registered with 0 damage points
# info       Pizza    140274312134224  register Pizza registered with 0 damage points
# info       Pizza    140274312132112  register Pizza registered with 0 damage points
# info       Pizza    140274312133776  register Pizza registered with 0 damage points
# info       Pizza    140274312130896  register Pizza registered with 0 damage points
# info       Pizza    140274312133712  register Pizza registered with 0 damage points
# info       Pizza    140274312134032  register Pizza registered with 0 damage points
# info       Pizza    140274312133840  register Pizza registered with 0 damage points

# %%
#@title Ecosystem Registry {display-mode: "code"}
'''
Create a code cell which uses the ecosystem registry to display
summary analysis for each robot kind
'''
for kind in ['Robot','Droid','Drone']:       #Iterating through all the robot kinds
  if kind == 'Robot':
    print('Number of robots:' + str(len(ecosystem.registry(kind=kind))))  #Printing the number of robots with the kind 'Robot' from the registry
  if kind == 'Droid':
    print('Number of droids:' + str(len(ecosystem.registry(kind=kind))))  #Printing the number of robots with the kind 'Droid' from the registry
  if kind == 'Drone':
    print('Number of drones:' + str(len(ecosystem.registry(kind=kind))))  #Printing the number of robots with the kind 'Drone' from the registry

# %%
#@title Tabulation {display-mode: "code"}
'''
Create a code cell which displays key metrics, including derived values as 
discussed in stage 3 introduction
See slides on stage 3 for the key attributes you should tabulate
'''

recorded = ecosystem.registry(kind_class= 'Robot')      #Calling the register of robots using the parent class Robot

#Printing the title headings for every column of info for the robots and spacing it out
print (f"{'name':<10} {'kind':<9} {'status':<9} {'service':<11} {'age':<9} {'active':<10} {'energy':<11} {'distance':<12} {'avg_Speed':<10} {'ser_rate':<10} {'avg_power':<10} {'energy_eff':<10}")

for key, value in recorded.items():      #Iterating through key value pairs in the dictionary
  name = value['name']
  kind = value['kind']
  status = value['status']
  service = value['service']
  age = value['age']
  active = value['active']
  energy = value['energy']
  distance = value['distance']
  

  avg_Speed = distance / active         #Adding extra performance results of the robots
  ser_rate = service / active
  avg_power = energy / active
  if service > 0:
    energy_eff = energy / service
  else:
    0
  
  #Printing the values under the key heading 
  print (f"{name:<10} {kind:<9} {status:<9} {service:<11} {age:<9} {active:<10} {energy:<11} {distance:<12.2f} {avg_Speed:<10.2f} {ser_rate:<10.2f} {avg_power:<10.2f} {energy_eff:<10.2f}")
# Out:
# name       kind      status    service     age       active     energy      distance     avg_Speed  ser_rate   avg_power  energy_eff
# drone0     Drone     on        1650        1001      1001       7274        2763.80      2.76       1.65       7.27       4.41
# drone1     Drone     on        1650        1001      1001       7313        2778.40      2.78       1.65       7.31       4.43
# drone2     Drone     on        1700        1001      1001       7020        2662.20      2.66       1.70       7.01       4.13
# drone3     Drone     on        1500        1001      1001       7262        2756.20      2.75       1.50       7.25       4.84
# drone4     Drone     on        1750        1001      1001       6956        2640.00      2.64       1.75       6.95       3.97
# robot5     Robot     on        500         1001      1001       6534        1095.60      1.09       0.50       6.53       13.07
# drone6     Drone     on        1350        1001      1001       7478        2839.60      2.84       1.35       7.47       5.54
# drone7     Drone     on        1350        1001      1001       7305        2770.20      2.77       1.35       7.30       5.41
# robot8     Robot     on        400         1001      1001       6650        1122.00      1.12       0.40       6.64       16.62
# drone9     Drone     on        1750        1001      1001       7212        2739.80      2.74       1.75       7.20       4.12
# droid10    Droid     on        1200        1001      1001       23630       2146.80      2.14       1.20       23.61      19.69
# drone11    Drone     on        1750        1001      1001       7132        2710.20      2.71       1.75       7.12       4.08

# %% [markdown]
# #**Stage 4 - Performance**
#
# This section is less prescriptive than the previous sections.
#
# It requires you to try and improve the performance as monitored by your work in stage 3
#
# The benchmark is the key performance indicators (KPIs) of an ecosystem with
#
#   * 5 robots of each kind
#   * An ecosystem duration of 1000 hours
#   * A maximum of **2** charging stations
#
# ##**KPIs**
#
# * $$Robot\ performance = \frac{Active\ hours}{Age} \  (ratio)$$
#
# * $$Service\ \ rate = \frac{Service}{Active\ hours} \  (kg.hour^{-1})$$
#
# * $$Energy\ \ efficiency\ \  = \frac{Energy}{Service} (kWh.kg^{-1} $$
#
# * $$Average\ \ Power\ \  = \frac{Energy}{Active\ hours}\ \ (kWh.hour^{-1} = kW)$$
#
# All these KPIs are affected by the operational efficiency of the Robots and this is determined by
# * poor allocation of pizzas to robots - does the nearest Robot get the next pizza!
# * poor charging decisions - often a robot has to head for the charger based on a low SOC when
#    1. it may have been able to collect the pizza it was heading for then headed to the charger.
#    2. it could have charged as it was passing the charger i.e. before SOC was too low
#    3. High risk taking resulting in robot's running out of charge
#
# So there are two things you can do:
# 1. Smarter allocation of pizzas to robots on a proximity basis.
# 2. Smarter charging algorithm.
#
#
# Do not deliver in your submission, additional or new Robot classes.
#
# Any changes you make to your robot classes in stage 1 should not 'break' earlier exercises!
#
#
# This section has no specific code cells - please organise as you choose.
#
# If you do incremental improvements with different measures, use a new codecell and show how the improvements unfold.
#
# Document your enhancements, and KPI improvements in the final text cell.

# %%
#@title KPI Improvements [code] {display-mode: "code"}

# Use this code cell and any subsequent ones to develop your KPI improvements

ecosystem = Ecosystem()
ecosystem.display_on_update = False
ecosystem.duration = 1000

#Operating robots - number of robots functioning over the total amount. Current hour is the current hour of the the display by the total amount it will go up to
ecosystem.display_parameters['title'] = 'Pick up, drop and charge - Operating robots: {operational} / '+ str(len(robotList)) +', Current hour: {hour} / {duration}'  
ecosystem.display_parameters['annotations'] = ['soc']

#Robot creation

robotList=[]                                         #A list for all the robots instantiated

for i in range(15):                                  #Creating 5 of each type of robot
  if i in range(0,5):
    robotList.append(Robot('robot' + str(i)))
  elif i in range(5,10):
    robotList.append(Droid('droid' + str(i)))
  else:
    robotList.append(Drone('drone' + str(i)))
    
for i in robotList:                                #Registering the robots and making them available to deliver pizzas when they appear
  i.activity = 'available'
  ecosystem.register(i)

#Charger creation

charger_1 = ecosystem.create('Grid_Charger', [27,20,0])          #Creating chargers in the ecosystem to power the robots back up 
charger_2 = ecosystem.create('Grid_Charger', [53,20,0])


pizzaList = []                                                 #Creating pizzas to go into this list

while ecosystem.stop == False and ecosystem.count_operational !=0:   #When the current hours are less than the total duration and when there is at least 1 robot
  for i in robotList:
    if i.kind == 'droid':                                           
      if i.soc/i.capacity <= 0.1:                                   #Setting %soc of droid to be lower as it has a much higher capacity than the drone and robot
        i.activity = 'charging'                                     #Setting the robot activity to charging when it goes below 10% of the charge capacity  
    else:                                                           
      if i.soc/i.capacity <= 0.4:                                   #Setting %soc of drone and robot to be 0.4 to allow it to have enough charge to return to the charger        
        i.activity = 'charging'

    #Assigning the charger to the robot
    if i.activity == 'charging':
      #Variables added to shorten down the length of code on a line
      x_dif_c = charger_1.coordinates[0] - i.coordinates[0]             #Difference in x - coords from charger_1 to robot
      y_dif_c = charger_1.coordinates[1] - i.coordinates[1]             #Difference in y - coords from charger_1 to robot
      x_dif_c2 = charger_2.coordinates[0] - i.coordinates[0]            #Difference in x - coords from charger_2 to robot
      y_dif_c2 = charger_2.coordinates[1] - i.coordinates[1]            #Difference in y - coords from charger_2 to robot

      if abs(x_dif_c) < abs(x_dif_c2) and abs(y_dif_c) < abs(y_dif_c2):   #Charger_1 is the station if both the x and y values from the robot to charger_1 is smaller than towards charger_2
        i.station = charger_1
      elif abs(x_dif_c) > abs(x_dif_c2) and abs(y_dif_c) > abs(y_dif_c2): #Charger_2 is the station if both the x and y values from the robot to charger_2 is smaller than towards charger_1
        i.station = charger_2
      else:                                                               #If the distance in x and y coords are the same to both chargers assign charger_2 as the station
        i.station = charger_2
 
      #Using pythagoras to assign the charger that is closest to the robot 
      if math.sqrt((x_dif_c)**2 + (y_dif_c)**2)  < math.sqrt((x_dif_c2)**2 + (y_dif_c2)**2):   #If the pythagoras of the diff in x,y coords from robot to charger_1 was smaller than to charger_2
        i.station = charger_1                                                                  #charger_1 is the station
      elif math.sqrt((x_dif_c)**2 + (y_dif_c)**2) == math.sqrt((x_dif_c2)**2 + (y_dif_c2)**2): #If the pythagoras of the diff in x,y coords from robot to charger_1 is equal to charger_2
        i.station = charger_1                                                                  #charger_1 is the station (,doesn't matter which charger it is)
      elif math.sqrt((x_dif_c)**2 + (y_dif_c)**2)  > math.sqrt((x_dif_c2)**2 + (y_dif_c2)**2): #If the pythagoras of the diff in x,y coords from robot to charger_1 was greater than to charger_2
        i.station = charger_2                                                                  #charger_2 is the station
      i.target = i.station.coordinates
      i.move()
    
    #Setting robot activity after charging has finished
    if i.soc/i.capacity >= 0.95:        
      i.station = None             #Removing the assigned station from the robot once it %soc is above 95%
      if i.cargo == None:
        i.activity = 'available'   #Setting the activity of the robot to available if it had no cargo after charging 
      else:
        i.activity = 'delivering'  #Robot activity set to delivering if it had cargo after charging

    #Creating pizzas and assigning cargo   
    if i.activity == 'available':
      pizzaList.append(ecosystem.create('Pizza'))  #Creating and adding pizzas to a list every time the loop is run
      i.cargo = pizzaList[-1]                      #The cargo of the robot is set to the latest pizza appended to the list
      i.activity = 'delivering'                    #Robot is delivering once it has a cargo assigned
   
    #Setting robot targets depending on the activity of the pizza and robot
    if i.activity == 'delivering':
      if i.cargo.status == 'awaiting_collection':
        i.target = i.cargo.coordinates
        i.move()
      elif i.cargo.status == 'in_transit':
        i.target = i.cargo.target
        i.move()
      elif i.cargo.status == 'delivered':
        i.cargo = None                        #Setting cargo to none when it has delivered so it can move off
        i.activity = 'available'              #Setting robot activity to available to allow it to go through the loop again
        i.move()
  ecosystem.update()                          #To update through the loop everytime 
ecosystem.display()
print(ecosystem.messages)
# Out:
# 1001
# info       Robot    140274310649616  register Robot registered with 0 damage points
# info       Robot    140274310649872  register Robot registered with 0 damage points
# info       Robot    140274310649680  register Robot registered with 0 damage points
# info       Robot    140274310649488  register Robot registered with 0 damage points
# info       Robot    140274310650000  register Robot registered with 0 damage points
# info       Droid    140274310649296  register Droid registered with 0 damage points
# info       Droid    140274310651216  register Droid registered with 0 damage points
# info       Droid    140274310649808  register Droid registered with 0 damage points
# info       Droid    140274310650896  register Droid registered with 0 damage points
# info       Droid    140274310650448  register Droid registered with 0 damage points
# info       Drone    140274310650768  register Drone registered with 0 damage points
# info       Drone    140274310651280  register Drone registered with 0 damage points
# info       Drone    140274310650640  register Drone registered with 0 damage points
# info       Drone    140274310651792  register Drone registered with 0 damage points
# info       Drone    140274310650512  register Drone registered with 0 damage points
# info       Grid_Charger 140274310650576  register Grid_Charger registered with 0 damage points
# info       Grid_Charger 140274310648848  register Grid_Charger registered with 0 damage points
# info       Pizza    140274310651856  register Pizza registered with 0 damage points
# info       Pizza    140274310651408  register Pizza registered with 0 damage points
# info       Pizza    140274310651536  register Pizza registered with 0 damage points
# info       Pizza    140274310651728  register Pizza registered with 0 damage points
# info       Pizza    140274314208080  register Pizza registered with 0 damage points
# info       Pizza    140274314207312  register Pizza registered with 0 damage points
# info       Pizza    140274314207952  register Pizza registered with 0 damage points
# info       Pizza    140274314207440  register Pizza registered with 0 damage points
# info       Pizza    140274314207632  register Pizza registered with 0 damage points
# info       Pizza    140274314208656  register Pizza registered with 0 damage points
# info       Pizza    140274314207568  register Pizza registered with 0 damage points
# info       Pizza    140274314208144  register Pizza registered with 0 damage points
# info       Pizza    140274314208208  register Pizza registered with 0 damage points
# info       Pizza    140274314208848  register Pizza registered with 0 damage points
# info       Pizza    140274314208912  register Pizza registered with 0 damage points
# info       Pizza    140274314209360  register Pizza registered with 0 damage points
# info       Pizza    140274314209104  register Pizza registered with 0 damage points
# info       Pizza    140274314209680  register Pizza registered with 0 damage points
# info       Pizza    140274314209808  register Pizza registered with 0 damage points
# info       Pizza    140274314208784  register Pizza registered with 0 damage points
# info       Pizza    140274314210640  register Pizza registered with 0 damage points
# info       Pizza    140274314209296  register Pizza registered with 0 damage points
# info       Pizza    140274314209040  register Pizza registered with 0 damage points
# info       Pizza    140274314210320  register Pizza registered with 0 damage points
# info       Pizza    140274314210128  register Pizza registered with 0 damage points
# info       Pizza    140274314210704  register Pizza registered with 0 damage points
# info       Pizza    140274314210512  register Pizza registered with 0 damage points
# info       Pizza    140274314211088  register Pizza registered with 0 damage points
# info       Pizza    140274314208592  register Pizza registered with 0 damage points
# info       Pizza    140274314208400  register Pizza registered with 0 damage points
# info       Pizza    140274314209744  register Pizza registered with 0 damage points
# info       Pizza    140274314210960  register Pizza registered with 0 damage points
# info       Pizza    140274314210768  register Pizza registered with 0 damage points
# info       Pizza    140274314211152  register Pizza registered with 0 damage points
# info       Pizza    140274314211216  register Pizza registered with 0 damage points
# info       Pizza    140274314272848  register Pizza registered with 0 damage points
# info       Pizza    140274314273296  register Pizza registered with 0 damage points
# info       Pizza    140274314276752  register Pizza registered with 0 damage points
# info       Pizza    140274314273360  register Pizza registered with 0 damage points
# info       Pizza    140274314273104  register Pizza registered with 0 damage points
# info       Pizza    140274314273744  register Pizza registered with 0 damage points
# info       Pizza    140274314273552  register Pizza registered with 0 damage points
# info       Pizza    140274314274000  register Pizza registered with 0 damage points
# info       Pizza    140274314273936  register Pizza registered with 0 damage points
# info       Pizza    140274314274448  register Pizza registered with 0 damage points
# info       Pizza    140274314275152  register Pizza registered with 0 damage points
# info       Pizza    140274314274832  register Pizza registered with 0 damage points
# info       Pizza    140274314274960  register Pizza registered with 0 damage points
# info       Pizza    140274314274768  register Pizza registered with 0 damage points
# info       Pizza    140274314272976  register Pizza registered with 0 damage points
# info       Pizza    140274314275728  register Pizza registered with 0 damage points
# info       Pizza    140274314275024  register Pizza registered with 0 damage points
# info       Pizza    140274314275088  register Pizza registered with 0 damage points
# info       Pizza    140274314276112  register Pizza registered with 0 damage points
# info       Pizza    140274314276048  register Pizza registered with 0 damage points
# info       Pizza    140274314275856  register Pizza registered with 0 damage points
# info       Pizza    140274329513488  register Pizza registered with 0 damage points
# info       Pizza    140274317662352  register Pizza registered with 0 damage points
# info       Pizza    140274317661840  register Pizza registered with 0 damage points
# info       Pizza    140274317660432  register Pizza registered with 0 damage points
# info       Pizza    140274317661712  register Pizza registered with 0 damage points
# info       Pizza    140274317662800  register Pizza registered with 0 damage points
# info       Pizza    140274317661072  register Pizza registered with 0 damage points
# info       Pizza    140274317661776  register Pizza registered with 0 damage points
# info       Pizza    140274317663248  register Pizza registered with 0 damage points
# info       Pizza    140274317663184  register Pizza registered with 0 damage points
# info       Pizza    140274317663888  register Pizza registered with 0 damage points
# info       Pizza    140274317661328  register Pizza registered with 0 damage points
# info       Pizza    140274317662096  register Pizza registered with 0 damage points
# info       Pizza    140274317660560  register Pizza registered with 0 damage points
# info       Pizza    140274317662224  register Pizza registered with 0 damage points
# info       Pizza    140274317661136  register Pizza registered with 0 damage points
# info       Pizza    140274317664144  register Pizza registered with 0 damage points
# info       Pizza    140274317662544  register Pizza registered with 0 damage points
# info       Pizza    140274317660496  register Pizza registered with 0 damage points
# info       Pizza    140274317660368  register Pizza registered with 0 damage points
# info       Pizza    140274317662288  register Pizza registered with 0 damage points
# info       Pizza    140274317662992  register Pizza registered with 0 damage points
# info       Pizza    140274317660688  register Pizza registered with 0 damage points
# info       Pizza    140274317662416  register Pizza registered with 0 damage points
# info       Pizza    140274317662160  register Pizza registered with 0 damage points
# info       Pizza    140274317661520  register Pizza registered with 0 damage points
# info       Pizza    140274317664208  register Pizza registered with 0 damage points
# info       Pizza    140274317663376  register Pizza registered with 0 damage points
# info       Pizza    140274317662480  register Pizza registered with 0 damage points
# info       Pizza    140274317663440  register Pizza registered with 0 damage points
# info       Pizza    140274317663568  register Pizza registered with 0 damage points
# info       Pizza    140274317663824  register Pizza registered with 0 damage points
# info       Pizza    140274317662864  register Pizza registered with 0 damage points
# info       Pizza    140274317703760  register Pizza registered with 0 damage points
# info       Pizza    140274317703248  register Pizza registered with 0 damage points
# info       Pizza    140274317703632  register Pizza registered with 0 damage points
# info       Pizza    140274317703888  register Pizza registered with 0 damage points
# info       Pizza    140274317701200  register Pizza registered with 0 damage points
# info       Pizza    140274317701456  register Pizza registered with 0 damage points
# info       Pizza    140274317701264  register Pizza registered with 0 damage points
# info       Pizza    140274317702800  register Pizza registered with 0 damage points
# info       Pizza    140274317701328  register Pizza registered with 0 damage points
# info       Pizza    140274314276368  register Pizza registered with 0 damage points
# info       Pizza    140274314275536  register Pizza registered with 0 damage points
# info       Pizza    140274314274128  register Pizza registered with 0 damage points
# info       Pizza    140274314274064  register Pizza registered with 0 damage points
# info       Pizza    140274314274576  register Pizza registered with 0 damage points
# info       Pizza    140274314276688  register Pizza registered with 0 damage points
# info       Pizza    140274314276176  register Pizza registered with 0 damage points
# info       Pizza    140274314276432  register Pizza registered with 0 damage points
# info       Pizza    140274317703568  register Pizza registered with 0 damage points
# info       Pizza    140274317702928  register Pizza registered with 0 damage points
# info       Pizza    140274317704208  register Pizza registered with 0 damage points
# info       Pizza    140274324016272  register Pizza registered with 0 damage points
# info       Pizza    140274324015824  register Pizza registered with 0 damage points
# info       Pizza    140274324014992  register Pizza registered with 0 damage points
# info       Pizza    140274324013904  register Pizza registered with 0 damage points
# info       Pizza    140274310648336  register Pizza registered with 0 damage points
# info       Pizza    140274324015696  register Pizza registered with 0 damage points
# info       Pizza    140274324015632  register Pizza registered with 0 damage points
# info       Pizza    140274324014032  register Pizza registered with 0 damage points
# info       Pizza    140274324015568  register Pizza registered with 0 damage points
# info       Pizza    140274324015312  register Pizza registered with 0 damage points
# info       Pizza    140274324014480  register Pizza registered with 0 damage points
# info       Pizza    140274324015184  register Pizza registered with 0 damage points
# info       Pizza    140274324015056  register Pizza registered with 0 damage points
# info       Pizza    140274324016464  register Pizza registered with 0 damage points
# info       Pizza    140274324015376  register Pizza registered with 0 damage points
# info       Pizza    140274324013584  register Pizza registered with 0 damage points
# info       Pizza    140274324016144  register Pizza registered with 0 damage points
# info       Pizza    140274324013200  register Pizza registered with 0 damage points
# info       Pizza    140274324014352  register Pizza registered with 0 damage points
# info       Pizza    140274324015248  register Pizza registered with 0 damage points
# info       Pizza    140274324014544  register Pizza registered with 0 damage points
# info       Pizza    140274324014608  register Pizza registered with 0 damage points
# info       Pizza    140274324016528  register Pizza registered with 0 damage points
# info       Pizza    140274324015504  register Pizza registered with 0 damage points
# info       Pizza    140274324014224  register Pizza registered with 0 damage points
# info       Pizza    140274324014096  register Pizza registered with 0 damage points
# info       Pizza    140274324016848  register Pizza registered with 0 damage points
# info       Pizza    140274324016656  register Pizza registered with 0 damage points
# info       Pizza    140274324015440  register Pizza registered with 0 damage points
# info       Pizza    140274324016080  register Pizza registered with 0 damage points
# info       Pizza    140274324014800  register Pizza registered with 0 damage points
# info       Pizza    140274320857680  register Pizza registered with 0 damage points
# info       Pizza    140274320857424  register Pizza registered with 0 damage points
# info       Pizza    140274314210064  register Pizza registered with 0 damage points
# info       Pizza    140274320856080  register Pizza registered with 0 damage points
# info       Pizza    140274320856848  register Pizza registered with 0 damage points
# info       Pizza    140274320856336  register Pizza registered with 0 damage points
# info       Pizza    140274320856656  register Pizza registered with 0 damage points
# info       Pizza    140274320856016  register Pizza registered with 0 damage points
# info       Pizza    140274320855952  register Pizza registered with 0 damage points
# info       Pizza    140274320855888  register Pizza registered with 0 damage points
# info       Pizza    140274320856784  register Pizza registered with 0 damage points
# info       Pizza    140274320858256  register Pizza registered with 0 damage points
# info       Pizza    140274320856464  register Pizza registered with 0 damage points
# info       Pizza    140274320856912  register Pizza registered with 0 damage points
# info       Pizza    140274320859024  register Pizza registered with 0 damage points
# info       Pizza    140274320855824  register Pizza registered with 0 damage points
# info       Pizza    140274320858448  register Pizza registered with 0 damage points
# info       Pizza    140274320858832  register Pizza registered with 0 damage points
# info       Pizza    140274320856720  register Pizza registered with 0 damage points
# info       Pizza    140274320857744  register Pizza registered with 0 damage points
# info       Pizza    140274320857360  register Pizza registered with 0 damage points
# info       Pizza    140274320857872  register Pizza registered with 0 damage points
# info       Pizza    140274320858576  register Pizza registered with 0 damage points
# info       Pizza    140274320857168  register Pizza registered with 0 damage points
# info       Pizza    140274320857808  register Pizza registered with 0 damage points
# info       Pizza    140274320858960  register Pizza registered with 0 damage points
# info       Pizza    140274320857296  register Pizza registered with 0 damage points
# info       Pizza    140274320889680  register Pizza registered with 0 damage points
# info       Pizza    140274320888464  register Pizza registered with 0 damage points
# info       Pizza    140274320889168  register Pizza registered with 0 damage points
# info       Pizza    140274320889552  register Pizza registered with 0 damage points
# info       Pizza    140274320890704  register Pizza registered with 0 damage points
# info       Pizza    140274320891280  register Pizza registered with 0 damage points
# info       Pizza    140274320888080  register Pizza registered with 0 damage points
# info       Pizza    140274320890128  register Pizza registered with 0 damage points
# info       Pizza    140274320888656  register Pizza registered with 0 damage points
# info       Pizza    140274320890000  register Pizza registered with 0 damage points
# info       Pizza    140274320888016  register Pizza registered with 0 damage points
# info       Pizza    140274320891536  register Pizza registered with 0 damage points
# info       Pizza    140274320887952  register Pizza registered with 0 damage points
# info       Pizza    140274320888336  register Pizza registered with 0 damage points
# info       Pizza    140274320887888  register Pizza registered with 0 damage points
# info       Pizza    140274320891216  register Pizza registered with 0 damage points
# info       Pizza    140274320891792  register Pizza registered with 0 damage points
# info       Pizza    140274320888848  register Pizza registered with 0 damage points
# info       Pizza    140274320888400  register Pizza registered with 0 damage points
# info       Pizza    140274320889424  register Pizza registered with 0 damage points
# info       Pizza    140274320891408  register Pizza registered with 0 damage points
# info       Pizza    140274320889616  register Pizza registered with 0 damage points
# info       Pizza    140274320888720  register Pizza registered with 0 damage points
# info       Pizza    140274320890448  register Pizza registered with 0 damage points
# info       Pizza    140274320888208  register Pizza registered with 0 damage points
# info       Pizza    140274320843024  register Pizza registered with 0 damage points
# info       Pizza    140274320843344  register Pizza registered with 0 damage points
# info       Pizza    140274320843408  register Pizza registered with 0 damage points
# info       Pizza    140274320843536  register Pizza registered with 0 damage points
# info       Pizza    140274320843152  register Pizza registered with 0 damage points
# info       Pizza    140274320843664  register Pizza registered with 0 damage points
# info       Pizza    140274320843920  register Pizza registered with 0 damage points
# info       Pizza    140274320843792  register Pizza registered with 0 damage points
# info       Pizza    140274320844112  register Pizza registered with 0 damage points
# info       Pizza    140274320844176  register Pizza registered with 0 damage points
# info       Pizza    140274320844624  register Pizza registered with 0 damage points
# info       Pizza    140274320844304  register Pizza registered with 0 damage points
# info       Pizza    140274320845200  register Pizza registered with 0 damage points
# info       Pizza    140274320845008  register Pizza registered with 0 damage points
# info       Pizza    140274320844368  register Pizza registered with 0 damage points
# info       Pizza    140274320844944  register Pizza registered with 0 damage points
# info       Pizza    140274320845264  register Pizza registered with 0 damage points
# info       Pizza    140274320845712  register Pizza registered with 0 damage points
# info       Pizza    140274320845456  register Pizza registered with 0 damage points
# info       Pizza    140274320845648  register Pizza registered with 0 damage points
# info       Pizza    140274320842896  register Pizza registered with 0 damage points
# info       Pizza    140274320845520  register Pizza registered with 0 damage points
# info       Pizza    140274320844688  register Pizza registered with 0 damage points
# info       Pizza    140274320844752  register Pizza registered with 0 damage points
# info       Pizza    140274320675024  register Pizza registered with 0 damage points
# info       Pizza    140274320675536  register Pizza registered with 0 damage points
# info       Pizza    140274320676176  register Pizza registered with 0 damage points
# info       Pizza    140274320678288  register Pizza registered with 0 damage points
# info       Pizza    140274320677200  register Pizza registered with 0 damage points
# info       Pizza    140274320674896  register Pizza registered with 0 damage points
# info       Pizza    140274320676752  register Pizza registered with 0 damage points
# info       Pizza    140274320677712  register Pizza registered with 0 damage points
# info       Pizza    140274320675280  register Pizza registered with 0 damage points
# info       Pizza    140274320678736  register Pizza registered with 0 damage points
# info       Pizza    140274320675728  register Pizza registered with 0 damage points
# info       Pizza    140274320677008  register Pizza registered with 0 damage points
# info       Pizza    140274320677456  register Pizza registered with 0 damage points
# info       Pizza    140274320677648  register Pizza registered with 0 damage points
# info       Pizza    140274320678032  register Pizza registered with 0 damage points
# info       Pizza    140274320678096  register Pizza registered with 0 damage points
# info       Pizza    140274320676048  register Pizza registered with 0 damage points
# info       Pizza    140274320675600  register Pizza registered with 0 damage points
# info       Pizza    140274320676240  register Pizza registered with 0 damage points
# info       Pizza    140274320675920  register Pizza registered with 0 damage points
# info       Pizza    140274320676112  register Pizza registered with 0 damage points
# info       Pizza    140274320676624  register Pizza registered with 0 damage points
# info       Pizza    140274320675152  register Pizza registered with 0 damage points
# info       Pizza    140274320676560  register Pizza registered with 0 damage points
# info       Pizza    140274309434448  register Pizza registered with 0 damage points
# info       Pizza    140274309431504  register Pizza registered with 0 damage points
# info       Pizza    140274309433744  register Pizza registered with 0 damage points
# info       Pizza    140274309433872  register Pizza registered with 0 damage points
# info       Pizza    140274309434512  register Pizza registered with 0 damage points
# info       Pizza    140274309432528  register Pizza registered with 0 damage points
# info       Pizza    140274309432464  register Pizza registered with 0 damage points
# info       Pizza    140274309432016  register Pizza registered with 0 damage points
# info       Pizza    140274309431440  register Pizza registered with 0 damage points
# info       Pizza    140274309433232  register Pizza registered with 0 damage points
# info       Pizza    140274309434640  register Pizza registered with 0 damage points
# info       Pizza    140274309434064  register Pizza registered with 0 damage points
# info       Pizza    140274309433296  register Pizza registered with 0 damage points
# info       Pizza    140274309433552  register Pizza registered with 0 damage points
# info       Pizza    140274308084048  register Pizza registered with 0 damage points
# info       Pizza    140274308085072  register Pizza registered with 0 damage points
# info       Pizza    140274308085136  register Pizza registered with 0 damage points
# info       Pizza    140274308085968  register Pizza registered with 0 damage points
# info       Pizza    140274308083920  register Pizza registered with 0 damage points
# info       Pizza    140274308083856  register Pizza registered with 0 damage points
# info       Pizza    140274308085520  register Pizza registered with 0 damage points
# info       Pizza    140274308086224  register Pizza registered with 0 damage points
# info       Pizza    140274308084112  register Pizza registered with 0 damage points
# info       Pizza    140274308087056  register Pizza registered with 0 damage points
# info       Pizza    140274308086928  register Pizza registered with 0 damage points
# info       Pizza    140274308087120  register Pizza registered with 0 damage points
# info       Pizza    140274308085712  register Pizza registered with 0 damage points
# info       Pizza    140274308087504  register Pizza registered with 0 damage points
# info       Pizza    140274308083792  register Pizza registered with 0 damage points
# info       Pizza    140274308087248  register Pizza registered with 0 damage points
# info       Pizza    140274308086160  register Pizza registered with 0 damage points
# info       Pizza    140274308085264  register Pizza registered with 0 damage points
# info       Pizza    140274308084880  register Pizza registered with 0 damage points
# info       Pizza    140274308084944  register Pizza registered with 0 damage points
# info       Pizza    140274308086992  register Pizza registered with 0 damage points
# info       Pizza    140274308083984  register Pizza registered with 0 damage points
# info       Pizza    140274308084304  register Pizza registered with 0 damage points
# info       Pizza    140274308085776  register Pizza registered with 0 damage points
# info       Pizza    140274308084496  register Pizza registered with 0 damage points
# info       Pizza    140274308087632  register Pizza registered with 0 damage points
# info       Pizza    140274308084432  register Pizza registered with 0 damage points
# info       Pizza    140274308087440  register Pizza registered with 0 damage points
# info       Pizza    140274308086480  register Pizza registered with 0 damage points
# info       Pizza    140274308085392  register Pizza registered with 0 damage points
# info       Pizza    140274314284816  register Pizza registered with 0 damage points
# info       Pizza    140274314282640  register Pizza registered with 0 damage points
# info       Pizza    140274314283216  register Pizza registered with 0 damage points
# info       Pizza    140274314284688  register Pizza registered with 0 damage points
# info       Pizza    140274314283664  register Pizza registered with 0 damage points
# info       Pizza    140274314281744  register Pizza registered with 0 damage points
# info       Pizza    140274314281680  register Pizza registered with 0 damage points
# info       Pizza    140274314281104  register Pizza registered with 0 damage points
# info       Pizza    140274314282320  register Pizza registered with 0 damage points
# info       Pizza    140274314281424  register Pizza registered with 0 damage points
# info       Pizza    140274314284304  register Pizza registered with 0 damage points
# info       Pizza    140274314282704  register Pizza registered with 0 damage points
# info       Pizza    140274314282000  register Pizza registered with 0 damage points
# info       Pizza    140274314283152  register Pizza registered with 0 damage points
# info       Pizza    140274314282576  register Pizza registered with 0 damage points
# info       Pizza    140274314283792  register Pizza registered with 0 damage points
# info       Pizza    140274314283984  register Pizza registered with 0 damage points
# info       Pizza    140274314283728  register Pizza registered with 0 damage points
# info       Pizza    140274314281232  register Pizza registered with 0 damage points
# info       Pizza    140274314283280  register Pizza registered with 0 damage points
# info       Pizza    140274314283472  register Pizza registered with 0 damage points
# info       Pizza    140274314284560  register Pizza registered with 0 damage points
# info       Pizza    140274314281168  register Pizza registered with 0 damage points
# info       Pizza    140274314281296  register Pizza registered with 0 damage points
# info       Pizza    140274314283344  register Pizza registered with 0 damage points
# info       Pizza    140274314284368  register Pizza registered with 0 damage points
# info       Pizza    140274314283600  register Pizza registered with 0 damage points
# info       Pizza    140274314281872  register Pizza registered with 0 damage points
# info       Pizza    140274314284624  register Pizza registered with 0 damage points
# info       Pizza    140274314281360  register Pizza registered with 0 damage points
# info       Pizza    140274314284112  register Pizza registered with 0 damage points
# info       Pizza    140274311385488  register Pizza registered with 0 damage points
# info       Pizza    140274311385744  register Pizza registered with 0 damage points
# info       Pizza    140274311388624  register Pizza registered with 0 damage points
# info       Pizza    140274311388240  register Pizza registered with 0 damage points
# info       Pizza    140274311385552  register Pizza registered with 0 damage points
# info       Pizza    140274311386640  register Pizza registered with 0 damage points
# info       Pizza    140274311388304  register Pizza registered with 0 damage points
# info       Pizza    140274311388176  register Pizza registered with 0 damage points
# info       Pizza    140274311387536  register Pizza registered with 0 damage points
# info       Pizza    140274311387600  register Pizza registered with 0 damage points
# info       Pizza    140274311385360  register Pizza registered with 0 damage points
# info       Pizza    140274311385680  register Pizza registered with 0 damage points
# info       Pizza    140274311386960  register Pizza registered with 0 damage points
# info       Pizza    140274311385296  register Pizza registered with 0 damage points
# info       Pizza    140274311385232  register Pizza registered with 0 damage points
# info       Pizza    140274311387664  register Pizza registered with 0 damage points
# info       Pizza    140274311388112  register Pizza registered with 0 damage points
# info       Pizza    140274311386512  register Pizza registered with 0 damage points
# info       Pizza    140274313049296  register Pizza registered with 0 damage points
# info       Pizza    140274313048208  register Pizza registered with 0 damage points
# info       Pizza    140274313048464  register Pizza registered with 0 damage points
# info       Pizza    140274313049424  register Pizza registered with 0 damage points
# info       Pizza    140274313049872  register Pizza registered with 0 damage points
# info       Pizza    140274313049232  register Pizza registered with 0 damage points
# info       Pizza    140274313049616  register Pizza registered with 0 damage points
# info       Pizza    140274313050640  register Pizza registered with 0 damage points
# info       Pizza    140274313051216  register Pizza registered with 0 damage points
# info       Pizza    140274313051408  register Pizza registered with 0 damage points
# info       Pizza    140274313050768  register Pizza registered with 0 damage points
# info       Pizza    140274313051472  register Pizza registered with 0 damage points
# info       Pizza    140274313048400  register Pizza registered with 0 damage points
# info       Pizza    140274313048720  register Pizza registered with 0 damage points
# info       Pizza    140274313050000  register Pizza registered with 0 damage points
# info       Pizza    140274313052048  register Pizza registered with 0 damage points
# info       Pizza    140274313049936  register Pizza registered with 0 damage points
# info       Pizza    140274313050384  register Pizza registered with 0 damage points
# info       Pizza    140274313048912  register Pizza registered with 0 damage points
# info       Pizza    140274313048528  register Pizza registered with 0 damage points
# info       Pizza    140274313050256  register Pizza registered with 0 damage points
# info       Pizza    140274313050320  register Pizza registered with 0 damage points
# info       Pizza    140274314291216  register Pizza registered with 0 damage points
# info       Pizza    140274314291536  register Pizza registered with 0 damage points
# info       Pizza    140274314292176  register Pizza registered with 0 damage points
# info       Pizza    140274314290448  register Pizza registered with 0 damage points
# info       Pizza    140274314291344  register Pizza registered with 0 damage points
# info       Pizza    140274314292112  register Pizza registered with 0 damage points
# info       Pizza    140274314292368  register Pizza registered with 0 damage points
# info       Pizza    140274314291152  register Pizza registered with 0 damage points
# info       Pizza    140274314290832  register Pizza registered with 0 damage points
# info       Pizza    140274314290064  register Pizza registered with 0 damage points
# info       Pizza    140274314291664  register Pizza registered with 0 damage points
# info       Pizza    140274314291728  register Pizza registered with 0 damage points
# info       Pizza    140274314293136  register Pizza registered with 0 damage points
# info       Pizza    140274314292752  register Pizza registered with 0 damage points
# info       Pizza    140274314291856  register Pizza registered with 0 damage points
# info       Pizza    140274314289424  register Pizza registered with 0 damage points
# info       Pizza    140274314290768  register Pizza registered with 0 damage points
# info       Pizza    140274314293200  register Pizza registered with 0 damage points
# info       Pizza    140274314291088  register Pizza registered with 0 damage points

# %%
for kind in ['Robot','Droid','Drone']:
  if kind == 'Robot':
    print('Number of robots:' + str(len(ecosystem.registry(kind=kind))))
  if kind == 'Droid':
    print('Number of droids:' + str(len(ecosystem.registry(kind=kind))))
  if kind == 'Drone':
    print('Number of drones:' + str(len(ecosystem.registry(kind=kind))))
# Out:
# Number of robots:5
# Number of droids:5
# Number of drones:5

# %%
recorded = ecosystem.registry(kind_class= 'Robot')

print (f"{'name':<10} {'kind':<9} {'status':<9} {'service':<11} {'age':<9} {'active':<10} {'energy':<11} {'distance':<12} {'avg_Speed':<10} {'ser_rate':<10} {'avg_power':<10} {'energy_eff':<10}")

for key, value in recorded.items():
  name = value['name']
  kind = value['kind']
  status = value['status']
  service = value['service']
  age = value['age']
  active = value['active']
  energy = value['energy']
  distance = value['distance']
  

  avg_Speed = distance / active
  ser_rate = service / active
  avg_power = energy / active
  if service > 0:
    energy_eff = energy / service
  else:
    0
  

  print (f"{name:<10} {kind:<9} {status:<9} {service:<11} {age:<9} {active:<10} {energy:<11} {distance:<12.2f} {avg_Speed:<10.2f} {ser_rate:<10.2f} {avg_power:<10.2f} {energy_eff:<10.2f}")
# Out:
# name       kind      status    service     age       active     energy      distance     avg_Speed  ser_rate   avg_power  energy_eff
# robot0     Robot     on        650         1001      1001       6704        1126.40      1.13       0.65       6.70       10.31
# robot1     Robot     on        600         1001      1001       6768        1140.40      1.14       0.60       6.76       11.28
# robot2     Robot     on        700         1001      1001       6745        1134.40      1.13       0.70       6.74       9.64
# robot3     Robot     on        650         1001      1001       6816        1149.00      1.15       0.65       6.81       10.49
# robot4     Robot     on        550         1001      1001       6711        1131.00      1.13       0.55       6.70       12.20
# droid5     Droid     on        1100        1001      1001       23749       2157.60      2.16       1.10       23.73      21.59
# droid6     Droid     on        1400        1001      1001       23578       2137.60      2.14       1.40       23.55      16.84
# droid7     Droid     on        1300        1001      1001       23057       2085.40      2.08       1.30       23.03      17.74
# droid8     Droid     on        1350        1001      1001       23298       2105.20      2.10       1.35       23.27      17.26
# droid9     Droid     on        1150        1001      1001       23545       2137.60      2.14       1.15       23.52      20.47
# drone10    Drone     on        1600        1001      1001       7390        2806.80      2.80       1.60       7.38       4.62
# drone11    Drone     on        1850        1001      1001       7239        2754.00      2.75       1.85       7.23       3.91
# drone12    Drone     on        1650        1001      1001       7284        2766.00      2.76       1.65       7.28       4.41
# drone13    Drone     on        1700        1001      1001       7032        2667.60      2.66       1.70       7.02       4.14
# drone14    Drone     on        1750        1001      1001       7090        2693.20      2.69       1.75       7.08       4.05

# %% [markdown]
# ##**KPI Improvement Summary**
#
# Please summarise your KPI improvements here and how you achieved them.

# %% [markdown]
# #**Summary and Conclusion**
#
# This coursework should have highlighted the use of OOP in software design.
# Summarise how the 4 main concepts of OOP (see WSA010 JNB08 Structured Programming.ipynb) have been employed in the Robot Ecosystem. Your answer should make specific reference to the objects, methods, attributes and any other code you have deployed in the courswork, and discuss OOPs suitability for this sort of application.
#
#  (500 words minimum - 1000 words maximum)

# %% [markdown]
# Create your answer here. You may use markdown but your answer will not be graded on its use.

# %% [markdown]
# #**Marking Schema**
#
# ***Please use your own work - do not plagiarise***
#
# |                            Section | Deliverable                                 | Marks | Section | Section % |
# |-----------------------------------:|---------------------------------------------|:-----:|:-------:|:---------:|
# |                      Robot Classes |                                             |       |    12   |    12%    |
# |                                    | Robot Class                                 |   4   |         |           |
# |                                    | Droid Class                                 |   4   |         |           |
# |                                    | Drone Class                                 |   4   |         |           |
# |            Stage 1 - Robot Classes |                                             |       |    8    |     8%    |
# |                                    | Test 1 Instantiation                        |   2   |         |           |
# |                                    | Test 2 Attributes Zone                      |   2   |         |           |
# |                                    | Test 3 -Robot Factory                       |   4   |         |           |
# | Stage 2 - Training and Development |                                             |       |    32   |    32%    |
# |                                    | Creating Pizzas                             |   2   |         |           |
# |                                    | Target and Move                             |   4   |         |           |
# |                                    | Deliveree                                   |   4   |         |           |
# |                                    | Work Till You Drop                          |   4   |         |           |
# |                                    | Factoree Deliveree                          |   6   |         |           |
# |                                    | Charger                                     |   4   |         |           |
# |                                    | Factory Delivery and Charging               |   8   |         |           |
# |     Stage 3 - Ecosystem Monitoring |                                             |       |    12   |    12%    |
# |                                    | Monitoring of Factory Delivery and Charging |   2   |         |           |
# |                                    | Ecosystem Registry                          |   2   |         |           |
# |                                    | Tabulation                                  |   8   |         |           |
# |              Stage 4 - Performance |                                             |       |    16   |    16%    |
# |                                    | KPI Improvements                            |   10  |         |           |
# |                                    | KPI Improvement Summary                     |   6   |         |           |
# |             Summary and Conclusion |                                             |       |    8    |     8%    |
# |                                    | 500-1000 words                              |   8   |         |           |
# |             Python Code Evaluation |                                             |       |    12   |    12%    |
# |                                    | Structured Code                             |   8   |         |           |
# |                                    | Readable code                               |   4   |         |           |
# |                                    |                                             |       |         |           |
# |                                    | Total                                       |  100  |   100   |    100%   |
